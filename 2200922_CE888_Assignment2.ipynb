# %% [markdown]
# ## 2200922 Assignment2

# %%
import pandas as pd
import os
import glob
import time
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, MinuteLocator
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S01/HR.csv')
df = df.iloc[2:]

start_date = '2022-02-07 09:27:00'
end_date = '2022-02-07 10:21:59'
time_range = pd.date_range(start=start_date, end=end_date, periods=len(df))

df['time'] = time_range
df['time'] = df['time'].dt.strftime('%H:%M:%S')

df = df.drop(df.columns[df.columns.str.contains('unnamed', case=False)], axis=1)

df.to_csv('S01_HR.csv', index=False)

# %%
df = pd.read_csv('C:/Users/tusha/Downloads/CE888/S01_HR.csv')


df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)

fig, ax = plt.subplots()
df.plot(ax=ax)

date_form = DateFormatter("%H:%M")
ax.xaxis.set_major_locator(MinuteLocator(interval=3))
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_tick_params(rotation=30, labelsize=10)

ax.set_ylabel('Heart Rate')

plt.show()

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s01 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S01/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s01), 64):
    avg = df_s01[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s01 = pd.DataFrame({'BVP': averages})
result_df_s01.to_csv('result_S01_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s01 = pd.read_csv('result_S01_BVP.csv')

start_time = 1644226061

df_s01['Time'] = [start_time + i for i in range(len(df_s01))]

df_s01.to_csv('S01_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s01 = pd.read_csv('S01_BVP.csv')

start_time_1 = 1644226140
end_time_1 = 1644226439
start_time_2 = 1644227092
end_time_2 = 1644227657
start_time_3 = 1644227991
end_time_3 = 1644228133
start_time_4 = 1644228446
end_time_4 = 1644228684

df_s01['Label'] = 0

df_s01.loc[(df_s01['Time'] >= start_time_1) & (df_s01['Time'] <= end_time_1), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_2) & (df_s01['Time'] <= end_time_2), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_3) & (df_s01['Time'] <= end_time_3), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_4) & (df_s01['Time'] <= end_time_4), 'Label'] = 1

df_s01.to_csv('S01_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s01 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S01/HR.csv')
df_s01 = df_s01.iloc[1:]

start_time = 1644226061

df_s01['Time'] = [start_time + i for i in range(len(df_s01))]

df_s01.to_csv('S01_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s01 = pd.read_csv('S01_HR.csv')

start_time_1 = 1644226140
end_time_1 = 1644226439
start_time_2 = 1644227092
end_time_2 = 1644227657
start_time_3 = 1644227991
end_time_3 = 1644228133
start_time_4 = 1644228446
end_time_4 = 1644228684

df_s01['Label'] = 0

df_s01.loc[(df_s01['Time'] >= start_time_1) & (df_s01['Time'] <= end_time_1), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_2) & (df_s01['Time'] <= end_time_2), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_3) & (df_s01['Time'] <= end_time_3), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_4) & (df_s01['Time'] <= end_time_4), 'Label'] = 1

df_s01.to_csv('S01_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s01 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S01/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s01), 4):
    avg = df_s01[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s01 = pd.DataFrame({'EDA': averages})
result_df_s01.to_csv('result_S01_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s01 = pd.read_csv('result_S01_EDA.csv')

start_time = 1644226061

df_s01['Time'] = [start_time + i for i in range(len(df_s01))]

df_s01.to_csv('S01_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s01 = pd.read_csv('S01_EDA.csv')

start_time_1 = 1644226140
end_time_1 = 1644226439
start_time_2 = 1644227092
end_time_2 = 1644227657
start_time_3 = 1644227991
end_time_3 = 1644228133
start_time_4 = 1644228446
end_time_4 = 1644228684

df_s01['Label'] = 0

df_s01.loc[(df_s01['Time'] >= start_time_1) & (df_s01['Time'] <= end_time_1), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_2) & (df_s01['Time'] <= end_time_2), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_3) & (df_s01['Time'] <= end_time_3), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_4) & (df_s01['Time'] <= end_time_4), 'Label'] = 1

df_s01.to_csv('S01_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s01 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S01/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s01), 4):
    avg = df_s01[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s01 = pd.DataFrame({'TEMP': averages})
result_df_s01.to_csv('result_S01_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s01 = pd.read_csv('result_S01_TEMP.csv')

start_time = 1644226061

df_s01['Time'] = [start_time + i for i in range(len(df_s01))]

df_s01.to_csv('S01_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s01 = pd.read_csv('S01_TEMP.csv')

start_time_1 = 1644226140
end_time_1 = 1644226439
start_time_2 = 1644227092
end_time_2 = 1644227657
start_time_3 = 1644227991
end_time_3 = 1644228133
start_time_4 = 1644228446
end_time_4 = 1644228684

df_s01['Label'] = 0

df_s01.loc[(df_s01['Time'] >= start_time_1) & (df_s01['Time'] <= end_time_1), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_2) & (df_s01['Time'] <= end_time_2), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_3) & (df_s01['Time'] <= end_time_3), 'Label'] = 1
df_s01.loc[(df_s01['Time'] >= start_time_4) & (df_s01['Time'] <= end_time_4), 'Label'] = 1

df_s01.to_csv('S01_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S01

# %%
df_HR = pd.read_csv('S01_HR_Label.csv')
df_BVP = pd.read_csv('S01_BVP_Label.csv')
df_EDA = pd.read_csv('S01_EDA_Label.csv')
df_TEMP = pd.read_csv('S01_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s01_merge = pd.merge(df_merge1, df_merge2)
df_s01_merge.to_csv('s01_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s02 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S02/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s02), 64):
    avg = df_s02[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s02 = pd.DataFrame({'BVP': averages})
result_df_s02.to_csv('result_S02_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s02 = pd.read_csv('result_S02_BVP.csv')

start_time = 1644227574

df_s02['Time'] = [start_time + i for i in range(len(df_s02))]

df_s02.to_csv('S02_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s02 = pd.read_csv('S02_BVP.csv')

start_time_1 = 1644228196
end_time_1 = 1644228572
start_time_2 = 1644228844
end_time_2 = 1644229499
start_time_3 = 1644229801
end_time_3 = 1644229931
start_time_4 = 1644230238
end_time_4 = 1644230562

df_s02['Label'] = 0

df_s02.loc[(df_s02['Time'] >= start_time_1) & (df_s02['Time'] <= end_time_1), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_2) & (df_s02['Time'] <= end_time_2), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_3) & (df_s02['Time'] <= end_time_3), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_4) & (df_s02['Time'] <= end_time_4), 'Label'] = 1

df_s02.to_csv('S02_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s02 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S02/HR.csv')
df_s02 = df_s02.iloc[1:]

start_time = 1644227584

df_s02['Time'] = [start_time + i for i in range(len(df_s02))]

df_s02.to_csv('S02_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s02 = pd.read_csv('S02_HR.csv')

start_time_1 = 1644228196
end_time_1 = 1644228572
start_time_2 = 1644228844
end_time_2 = 1644229499
start_time_3 = 1644229801
end_time_3 = 1644229931
start_time_4 = 1644230238
end_time_4 = 1644230562

df_s02['Label'] = 0

df_s02.loc[(df_s02['Time'] >= start_time_1) & (df_s02['Time'] <= end_time_1), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_2) & (df_s02['Time'] <= end_time_2), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_3) & (df_s02['Time'] <= end_time_3), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_4) & (df_s02['Time'] <= end_time_4), 'Label'] = 1

df_s02.to_csv('S02_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s02 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S02/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s02), 4):
    avg = df_s02[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s02 = pd.DataFrame({'EDA': averages})
result_df_s02.to_csv('result_S02_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s02 = pd.read_csv('result_S02_EDA.csv')

start_time = 1644227574

df_s02['Time'] = [start_time + i for i in range(len(df_s02))]

df_s02.to_csv('S02_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s02 = pd.read_csv('S02_EDA.csv')

start_time_1 = 1644228196
end_time_1 = 1644228572
start_time_2 = 1644228844
end_time_2 = 1644229499
start_time_3 = 1644229801
end_time_3 = 1644229931
start_time_4 = 1644230238
end_time_4 = 1644230562

df_s02['Label'] = 0

df_s02.loc[(df_s02['Time'] >= start_time_1) & (df_s02['Time'] <= end_time_1), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_2) & (df_s02['Time'] <= end_time_2), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_3) & (df_s02['Time'] <= end_time_3), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_4) & (df_s02['Time'] <= end_time_4), 'Label'] = 1

df_s02.to_csv('S02_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s02 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S02/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s02), 4):
    avg = df_s02[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s02 = pd.DataFrame({'TEMP': averages})
result_df_s02.to_csv('result_S02_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s02 = pd.read_csv('result_S02_TEMP.csv')

start_time = 1644227574

df_s02['Time'] = [start_time + i for i in range(len(df_s02))]

df_s02.to_csv('S02_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s02 = pd.read_csv('S02_TEMP.csv')

start_time_1 = 1644228196
end_time_1 = 1644228572
start_time_2 = 1644228844
end_time_2 = 1644229499
start_time_3 = 1644229801
end_time_3 = 1644229931
start_time_4 = 1644230238
end_time_4 = 1644230562

df_s02['Label'] = 0

df_s02.loc[(df_s02['Time'] >= start_time_1) & (df_s02['Time'] <= end_time_1), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_2) & (df_s02['Time'] <= end_time_2), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_3) & (df_s02['Time'] <= end_time_3), 'Label'] = 1
df_s02.loc[(df_s02['Time'] >= start_time_4) & (df_s02['Time'] <= end_time_4), 'Label'] = 1

df_s02.to_csv('S02_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S02

# %%
df_HR = pd.read_csv('S02_HR_Label.csv')
df_BVP = pd.read_csv('S02_BVP_Label.csv')
df_EDA = pd.read_csv('S02_EDA_Label.csv')
df_TEMP = pd.read_csv('S02_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s02_merge = pd.merge(df_merge1, df_merge2)
df_s02_merge.to_csv('s02_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s03 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S03/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s03), 64):
    avg = df_s03[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s03 = pd.DataFrame({'BVP': averages})
result_df_s03.to_csv('result_S03_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s03 = pd.read_csv('result_S03_BVP.csv')

start_time = 1644231372

df_s03['Time'] = [start_time + i for i in range(len(df_s03))]

df_s03.to_csv('S03_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s03 = pd.read_csv('S03_BVP.csv')

start_time_1 = 1644231934
end_time_1 = 1644232210
start_time_2 = 1644232484
end_time_2 = 1644233026
start_time_3 = 1644233339
end_time_3 = 1644233488
start_time_4 = 1644233765
end_time_4 = 1644233995


df_s03['Label'] = 0

df_s03.loc[(df_s03['Time'] >= start_time_1) & (df_s03['Time'] <= end_time_1), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_2) & (df_s03['Time'] <= end_time_2), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_3) & (df_s03['Time'] <= end_time_3), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_4) & (df_s03['Time'] <= end_time_4), 'Label'] = 1

df_s03.to_csv('S03_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s03 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S03/HR.csv')
df_s03 = df_s03.iloc[1:]

start_time = 1644231382

df_s03['Time'] = [start_time + i for i in range(len(df_s03))]


df_s03.to_csv('S03_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s03 = pd.read_csv('S03_HR.csv')

start_time_1 = 1644231934
end_time_1 = 1644232210
start_time_2 = 1644232484
end_time_2 = 1644233026
start_time_3 = 1644233339
end_time_3 = 1644233488
start_time_4 = 1644233765
end_time_4 = 1644233995


df_s03['Label'] = 0

df_s03.loc[(df_s03['Time'] >= start_time_1) & (df_s03['Time'] <= end_time_1), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_2) & (df_s03['Time'] <= end_time_2), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_3) & (df_s03['Time'] <= end_time_3), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_4) & (df_s03['Time'] <= end_time_4), 'Label'] = 1

df_s03.to_csv('S03_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s03 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S03/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s03), 4):
    avg = df_s03[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s03 = pd.DataFrame({'EDA': averages})
result_df_s03.to_csv('result_S03_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s03 = pd.read_csv('result_S03_EDA.csv')

start_time = 1644231372

df_s03['Time'] = [start_time + i for i in range(len(df_s03))]

df_s03.to_csv('S03_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s03 = pd.read_csv('S03_EDA.csv')

start_time_1 = 1644231934
end_time_1 = 1644232210
start_time_2 = 1644232484
end_time_2 = 1644233026
start_time_3 = 1644233339
end_time_3 = 1644233488
start_time_4 = 1644233765
end_time_4 = 1644233995

df_s03['Label'] = 0

df_s03.loc[(df_s03['Time'] >= start_time_1) & (df_s03['Time'] <= end_time_1), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_2) & (df_s03['Time'] <= end_time_2), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_3) & (df_s03['Time'] <= end_time_3), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_4) & (df_s03['Time'] <= end_time_4), 'Label'] = 1

df_s03.to_csv('S03_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s03 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S03/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s03), 4):
    avg = df_s03[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s03 = pd.DataFrame({'TEMP': averages})
result_df_s03.to_csv('result_S03_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s03 = pd.read_csv('result_S03_TEMP.csv')

start_time = 1644231372

df_s03['Time'] = [start_time + i for i in range(len(df_s03))]


df_s03.to_csv('S03_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s03 = pd.read_csv('S03_TEMP.csv')

start_time_1 = 1644231934
end_time_1 = 1644232210
start_time_2 = 1644232484
end_time_2 = 1644233026
start_time_3 = 1644233339
end_time_3 = 1644233488
start_time_4 = 1644233765
end_time_4 = 1644233995

df_s03['Label'] = 0

df_s03.loc[(df_s03['Time'] >= start_time_1) & (df_s03['Time'] <= end_time_1), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_2) & (df_s03['Time'] <= end_time_2), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_3) & (df_s03['Time'] <= end_time_3), 'Label'] = 1
df_s03.loc[(df_s03['Time'] >= start_time_4) & (df_s03['Time'] <= end_time_4), 'Label'] = 1

df_s03.to_csv('S03_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S03

# %%
df_HR = pd.read_csv('S03_HR_Label.csv')
df_BVP = pd.read_csv('S03_BVP_Label.csv')
df_EDA = pd.read_csv('S03_EDA_Label.csv')
df_TEMP = pd.read_csv('S03_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s03_merge = pd.merge(df_merge1, df_merge2)
df_s03_merge.to_csv('s03_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s04 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S04/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s04), 64):
    avg = df_s04[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s04 = pd.DataFrame({'BVP': averages})
result_df_s04.to_csv('result_S04_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s04 = pd.read_csv('result_S04_BVP.csv')

start_time = 1644233389

df_s04['Time'] = [start_time + i for i in range(len(df_s04))]

df_s04.to_csv('S04_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s04 = pd.read_csv('S04_BVP.csv')

start_time_1 = 1644233954
end_time_1 = 1644234298
start_time_2 = 1644234583
end_time_2 = 1644235183
start_time_3 = 1644235484
end_time_3 = 1644235614
start_time_4 = 1644235916
end_time_4 = 1644236319

df_s04['Label'] = 0

df_s04.loc[(df_s04['Time'] >= start_time_1) & (df_s04['Time'] <= end_time_1), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_2) & (df_s04['Time'] <= end_time_2), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_3) & (df_s04['Time'] <= end_time_3), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_4) & (df_s04['Time'] <= end_time_4), 'Label'] = 1

df_s04.to_csv('S04_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s04 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S04/HR.csv')
df_s04 = df_s04.iloc[1:]

start_time = 1644233399

df_s04['Time'] = [start_time + i for i in range(len(df_s04))]

df_s04.to_csv('S04_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s04 = pd.read_csv('S04_HR.csv')

start_time_1 = 1644233954
end_time_1 = 1644234298
start_time_2 = 1644234583
end_time_2 = 1644235183
start_time_3 = 1644235484
end_time_3 = 1644235614
start_time_4 = 1644235916
end_time_4 = 1644236319

df_s04['Label'] = 0

df_s04.loc[(df_s04['Time'] >= start_time_1) & (df_s04['Time'] <= end_time_1), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_2) & (df_s04['Time'] <= end_time_2), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_3) & (df_s04['Time'] <= end_time_3), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_4) & (df_s04['Time'] <= end_time_4), 'Label'] = 1

df_s04.to_csv('S04_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s04 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S04/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s04), 4):
    avg = df_s04[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s04 = pd.DataFrame({'EDA': averages})
result_df_s04.to_csv('result_S04_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s04 = pd.read_csv('result_S04_EDA.csv')

start_time = 1644233389

df_s04['Time'] = [start_time + i for i in range(len(df_s04))]

df_s04.to_csv('S04_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s04 = pd.read_csv('S04_EDA.csv')

start_time_1 = 1644233954
end_time_1 = 1644234298
start_time_2 = 1644234583
end_time_2 = 1644235183
start_time_3 = 1644235484
end_time_3 = 1644235614
start_time_4 = 1644235916
end_time_4 = 1644236319

df_s04['Label'] = 0

df_s04.loc[(df_s04['Time'] >= start_time_1) & (df_s04['Time'] <= end_time_1), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_2) & (df_s04['Time'] <= end_time_2), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_3) & (df_s04['Time'] <= end_time_3), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_4) & (df_s04['Time'] <= end_time_4), 'Label'] = 1

df_s04.to_csv('S04_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s04 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S04/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s04), 4):
    avg = df_s04[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s04 = pd.DataFrame({'TEMP': averages})
result_df_s04.to_csv('result_S04_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s04 = pd.read_csv('result_S04_TEMP.csv')

start_time = 1644233389

df_s04['Time'] = [start_time + i for i in range(len(df_s04))]

df_s04.to_csv('S04_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s04 = pd.read_csv('S04_TEMP.csv')

start_time_1 = 1644233954
end_time_1 = 1644234298
start_time_2 = 1644234583
end_time_2 = 1644235183
start_time_3 = 1644235484
end_time_3 = 1644235614
start_time_4 = 1644235916
end_time_4 = 1644236319

df_s04['Label'] = 0

df_s04.loc[(df_s04['Time'] >= start_time_1) & (df_s04['Time'] <= end_time_1), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_2) & (df_s04['Time'] <= end_time_2), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_3) & (df_s04['Time'] <= end_time_3), 'Label'] = 1
df_s04.loc[(df_s04['Time'] >= start_time_4) & (df_s04['Time'] <= end_time_4), 'Label'] = 1

df_s04.to_csv('S04_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S04

# %%
df_HR = pd.read_csv('S04_HR_Label.csv')
df_BVP = pd.read_csv('S04_BVP_Label.csv')
df_EDA = pd.read_csv('S04_EDA_Label.csv')
df_TEMP = pd.read_csv('S04_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s04_merge = pd.merge(df_merge1, df_merge2)
df_s04_merge.to_csv('s04_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s05 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S05/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s05), 64):
    avg = df_s05[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s05 = pd.DataFrame({'BVP': averages})
result_df_s05.to_csv('result_S05_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s05 = pd.read_csv('result_S05_BVP.csv')

start_time = 1644829925

df_s05['Time'] = [start_time + i for i in range(len(df_s05))]

df_s05.to_csv('S05_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s05 = pd.read_csv('S05_BVP.csv')

start_time_1 = 1644830599
end_time_1 = 1644830945
start_time_2 = 1644831216
end_time_2 = 1644831861
start_time_3 = 1644832127
end_time_3 = 1644832248
start_time_4 = 1644832555
end_time_4 = 1644832859

df_s05['Label'] = 0

df_s05.loc[(df_s05['Time'] >= start_time_1) & (df_s05['Time'] <= end_time_1), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_2) & (df_s05['Time'] <= end_time_2), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_3) & (df_s05['Time'] <= end_time_3), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_4) & (df_s05['Time'] <= end_time_4), 'Label'] = 1

df_s05.to_csv('S05_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s05 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S05/HR.csv')
df_s05 = df_s05.iloc[1:]

start_time = 1644829935

df_s05['Time'] = [start_time + i for i in range(len(df_s05))]

df_s05.to_csv('S05_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s05 = pd.read_csv('S05_HR.csv')

start_time_1 = 1644830599
end_time_1 = 1644830945
start_time_2 = 1644831216
end_time_2 = 1644831861
start_time_3 = 1644832127
end_time_3 = 1644832248
start_time_4 = 1644832555
end_time_4 = 1644832859

df_s05['Label'] = 0

df_s05.loc[(df_s05['Time'] >= start_time_1) & (df_s05['Time'] <= end_time_1), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_2) & (df_s05['Time'] <= end_time_2), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_3) & (df_s05['Time'] <= end_time_3), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_4) & (df_s05['Time'] <= end_time_4), 'Label'] = 1

df_s05.to_csv('S05_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s05 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S05/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s05), 4):
    avg = df_s05[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s05 = pd.DataFrame({'EDA': averages})
result_df_s05.to_csv('result_S05_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s05 = pd.read_csv('result_S05_EDA.csv')

start_time = 1644829925

df_s05['Time'] = [start_time + i for i in range(len(df_s05))]

df_s05.to_csv('S05_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s05 = pd.read_csv('S05_EDA.csv')

start_time_1 = 1644830599
end_time_1 = 1644830945
start_time_2 = 1644831216
end_time_2 = 1644831861
start_time_3 = 1644832127
end_time_3 = 1644832248
start_time_4 = 1644832555
end_time_4 = 1644832859

df_s05['Label'] = 0

df_s05.loc[(df_s05['Time'] >= start_time_1) & (df_s05['Time'] <= end_time_1), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_2) & (df_s05['Time'] <= end_time_2), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_3) & (df_s05['Time'] <= end_time_3), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_4) & (df_s05['Time'] <= end_time_4), 'Label'] = 1

df_s05.to_csv('S05_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s05 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S05/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s05), 4):
    avg = df_s05[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s05 = pd.DataFrame({'TEMP': averages})
result_df_s05.to_csv('result_S05_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s05 = pd.read_csv('result_S05_TEMP.csv')

start_time = 1644829925

df_s05['Time'] = [start_time + i for i in range(len(df_s05))]

df_s05.to_csv('S05_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s05 = pd.read_csv('S05_TEMP.csv')

start_time_1 = 1644830599
end_time_1 = 1644830945
start_time_2 = 1644831216
end_time_2 = 1644831861
start_time_3 = 1644832127
end_time_3 = 1644832248
start_time_4 = 1644832555
end_time_4 = 1644832859

df_s05['Label'] = 0

df_s05.loc[(df_s05['Time'] >= start_time_1) & (df_s05['Time'] <= end_time_1), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_2) & (df_s05['Time'] <= end_time_2), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_3) & (df_s05['Time'] <= end_time_3), 'Label'] = 1
df_s05.loc[(df_s05['Time'] >= start_time_4) & (df_s05['Time'] <= end_time_4), 'Label'] = 1

df_s05.to_csv('S05_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S05

# %%
df_HR = pd.read_csv('S05_HR_Label.csv')
df_BVP = pd.read_csv('S05_BVP_Label.csv')
df_EDA = pd.read_csv('S05_EDA_Label.csv')
df_TEMP = pd.read_csv('S05_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s05_merge = pd.merge(df_merge1, df_merge2)
df_s05_merge.to_csv('s05_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s06 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S06/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s06), 64):
    avg = df_s06[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s06 = pd.DataFrame({'BVP': averages})
result_df_s06.to_csv('result_S06_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s06 = pd.read_csv('result_S06_BVP.csv')

start_time = 1644831900

df_s06['Time'] = [start_time + i for i in range(len(df_s06))]

df_s06.to_csv('S06_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s06 = pd.read_csv('S06_BVP.csv')

start_time_1 = 1644832500
end_time_1 = 1644832920
start_time_2 = 1644833220
end_time_2 = 1644833880
start_time_3 = 1644834176
end_time_3 = 1644834333
start_time_4 = 1644834617
end_time_4 = 1644834913

df_s06['Label'] = 0

df_s06.loc[(df_s06['Time'] >= start_time_1) & (df_s06['Time'] <= end_time_1), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_2) & (df_s06['Time'] <= end_time_2), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_3) & (df_s06['Time'] <= end_time_3), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_4) & (df_s06['Time'] <= end_time_4), 'Label'] = 1

df_s06.to_csv('S06_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s06 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S06/HR.csv')
df_s06 = df_s06.iloc[1:]

start_time = 1644831910

df_s06['Time'] = [start_time + i for i in range(len(df_s06))]

df_s06.to_csv('S06_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s06 = pd.read_csv('S06_HR.csv')

start_time_1 = 1644832500
end_time_1 = 1644832920
start_time_2 = 1644833220
end_time_2 = 1644833880
start_time_3 = 1644834176
end_time_3 = 1644834333
start_time_4 = 1644834617
end_time_4 = 1644834913

df_s06['Label'] = 0

df_s06.loc[(df_s06['Time'] >= start_time_1) & (df_s06['Time'] <= end_time_1), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_2) & (df_s06['Time'] <= end_time_2), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_3) & (df_s06['Time'] <= end_time_3), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_4) & (df_s06['Time'] <= end_time_4), 'Label'] = 1

df_s06.to_csv('S06_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s06 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S06/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s06), 4):
    avg = df_s06[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s06 = pd.DataFrame({'EDA': averages})
result_df_s06.to_csv('result_S06_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s06 = pd.read_csv('result_S06_EDA.csv')

start_time = 1644831900

df_s06['Time'] = [start_time + i for i in range(len(df_s06))]

df_s06.to_csv('S06_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s06 = pd.read_csv('S06_EDA.csv')

start_time_1 = 1644832500
end_time_1 = 1644832920
start_time_2 = 1644833220
end_time_2 = 1644833880
start_time_3 = 1644834176
end_time_3 = 1644834333
start_time_4 = 1644834617
end_time_4 = 1644834913

df_s06['Label'] = 0

df_s06.loc[(df_s06['Time'] >= start_time_1) & (df_s06['Time'] <= end_time_1), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_2) & (df_s06['Time'] <= end_time_2), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_3) & (df_s06['Time'] <= end_time_3), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_4) & (df_s06['Time'] <= end_time_4), 'Label'] = 1

df_s06.to_csv('S06_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s06 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S06/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s06), 4):
    avg = df_s06[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s06 = pd.DataFrame({'TEMP': averages})
result_df_s06.to_csv('result_S06_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s06 = pd.read_csv('result_S06_TEMP.csv')

start_time = 1644831900

df_s06['Time'] = [start_time + i for i in range(len(df_s06))]

df_s06.to_csv('S06_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s06 = pd.read_csv('S06_TEMP.csv')

start_time_1 = 1644832500
end_time_1 = 1644832920
start_time_2 = 1644833220
end_time_2 = 1644833880
start_time_3 = 1644834176
end_time_3 = 1644834333
start_time_4 = 1644834617
end_time_4 = 1644834913

df_s06['Label'] = 0

df_s06.loc[(df_s06['Time'] >= start_time_1) & (df_s06['Time'] <= end_time_1), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_2) & (df_s06['Time'] <= end_time_2), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_3) & (df_s06['Time'] <= end_time_3), 'Label'] = 1
df_s06.loc[(df_s06['Time'] >= start_time_4) & (df_s06['Time'] <= end_time_4), 'Label'] = 1

df_s06.to_csv('S06_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S06

# %%
df_HR = pd.read_csv('S06_HR_Label.csv')
df_BVP = pd.read_csv('S06_BVP_Label.csv')
df_EDA = pd.read_csv('S06_EDA_Label.csv')
df_TEMP = pd.read_csv('S06_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s06_merge = pd.merge(df_merge1, df_merge2)
df_s06_merge.to_csv('s06_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s07 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S07/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s07), 64):
    avg = df_s07[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s07 = pd.DataFrame({'BVP': averages})
result_df_s07.to_csv('result_S07_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s07 = pd.read_csv('result_S07_BVP.csv')

start_time = 1644834634

df_s07['Time'] = [start_time + i for i in range(len(df_s07))]

df_s07.to_csv('S07_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s07 = pd.read_csv('S07_BVP.csv')

start_time_1 = 1644835409
end_time_1 = 1644835667
start_time_2 = 1644835937
end_time_2 = 1644836550
start_time_3 = 1644836901
end_time_3 = 1644837040
start_time_4 = 1644837375
end_time_4 = 1644837675


df_s07['Label'] = 0

df_s07.loc[(df_s07['Time'] >= start_time_1) & (df_s07['Time'] <= end_time_1), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_2) & (df_s07['Time'] <= end_time_2), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_3) & (df_s07['Time'] <= end_time_3), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_4) & (df_s07['Time'] <= end_time_4), 'Label'] = 1

df_s07.to_csv('S07_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s07 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S07/HR.csv')
df_s07 = df_s07.iloc[1:]

start_time = 1644834644

df_s07['Time'] = [start_time + i for i in range(len(df_s07))]

df_s07.to_csv('S07_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s07 = pd.read_csv('S07_HR.csv')

start_time_1 = 1644835409
end_time_1 = 1644835667
start_time_2 = 1644835937
end_time_2 = 1644836550
start_time_3 = 1644836901
end_time_3 = 1644837040
start_time_4 = 1644837375
end_time_4 = 1644837675

df_s07['Label'] = 0

df_s07.loc[(df_s07['Time'] >= start_time_1) & (df_s07['Time'] <= end_time_1), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_2) & (df_s07['Time'] <= end_time_2), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_3) & (df_s07['Time'] <= end_time_3), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_4) & (df_s07['Time'] <= end_time_4), 'Label'] = 1

df_s07.to_csv('S07_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s07 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S07/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s07), 4):
    avg = df_s07[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s07 = pd.DataFrame({'EDA': averages})
result_df_s07.to_csv('result_S07_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s07 = pd.read_csv('result_S07_EDA.csv')

start_time = 1644834634

df_s07['Time'] = [start_time + i for i in range(len(df_s07))]

df_s07.to_csv('S07_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s07 = pd.read_csv('S07_EDA.csv')

start_time_1 = 1644835409
end_time_1 = 1644835667
start_time_2 = 1644835937
end_time_2 = 1644836550
start_time_3 = 1644836901
end_time_3 = 1644837040
start_time_4 = 1644837375
end_time_4 = 1644837675

df_s07['Label'] = 0

df_s07.loc[(df_s07['Time'] >= start_time_1) & (df_s07['Time'] <= end_time_1), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_2) & (df_s07['Time'] <= end_time_2), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_3) & (df_s07['Time'] <= end_time_3), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_4) & (df_s07['Time'] <= end_time_4), 'Label'] = 1

df_s07.to_csv('S07_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s07 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S07/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s07), 4):
    avg = df_s07[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s07 = pd.DataFrame({'TEMP': averages})
result_df_s07.to_csv('result_S07_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s07 = pd.read_csv('result_S07_TEMP.csv')

start_time = 1644834634

df_s07['Time'] = [start_time + i for i in range(len(df_s07))]

df_s07.to_csv('S07_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s07 = pd.read_csv('S07_TEMP.csv')

start_time_1 = 1644835409
end_time_1 = 1644835667
start_time_2 = 1644835937
end_time_2 = 1644836550
start_time_3 = 1644836901
end_time_3 = 1644837040
start_time_4 = 1644837375
end_time_4 = 1644837675

df_s07['Label'] = 0

df_s07.loc[(df_s07['Time'] >= start_time_1) & (df_s07['Time'] <= end_time_1), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_2) & (df_s07['Time'] <= end_time_2), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_3) & (df_s07['Time'] <= end_time_3), 'Label'] = 1
df_s07.loc[(df_s07['Time'] >= start_time_4) & (df_s07['Time'] <= end_time_4), 'Label'] = 1

df_s07.to_csv('S07_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S07

# %%
df_HR = pd.read_csv('S07_HR_Label.csv')
df_BVP = pd.read_csv('S07_BVP_Label.csv')
df_EDA = pd.read_csv('S07_EDA_Label.csv')
df_TEMP = pd.read_csv('S07_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s07_merge = pd.merge(df_merge1, df_merge2)
df_s07_merge.to_csv('s07_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s08 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S08/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s08), 64):
    avg = df_s08[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s08 = pd.DataFrame({'BVP': averages})
result_df_s08.to_csv('result_S08_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s08 = pd.read_csv('result_S08_BVP.csv')

start_time = 1644840744

df_s08['Time'] = [start_time + i for i in range(len(df_s08))]

df_s08.to_csv('S08_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s08 = pd.read_csv('S08_BVP.csv')

start_time_1 = 1644841379
end_time_1 = 1644841698
start_time_2 = 1644842006
end_time_2 = 1644842586
start_time_3 = 1644842880
end_time_3 = 1644842992
start_time_4 = 1644843281
end_time_4 = 1644843581

df_s08['Label'] = 0

df_s08.loc[(df_s08['Time'] >= start_time_1) & (df_s08['Time'] <= end_time_1), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_2) & (df_s08['Time'] <= end_time_2), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_3) & (df_s08['Time'] <= end_time_3), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_4) & (df_s08['Time'] <= end_time_4), 'Label'] = 1

df_s08.to_csv('S08_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s08 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S08/HR.csv')
df_s08 = df_s08.iloc[1:]

start_time = 1644840754

df_s08['Time'] = [start_time + i for i in range(len(df_s08))]

df_s08.to_csv('S08_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s08 = pd.read_csv('S08_HR.csv')

start_time_1 = 1644841379
end_time_1 = 1644841698
start_time_2 = 1644842006
end_time_2 = 1644842586
start_time_3 = 1644842880
end_time_3 = 1644842992
start_time_4 = 1644843281
end_time_4 = 1644843581

df_s08['Label'] = 0

df_s08.loc[(df_s08['Time'] >= start_time_1) & (df_s08['Time'] <= end_time_1), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_2) & (df_s08['Time'] <= end_time_2), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_3) & (df_s08['Time'] <= end_time_3), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_4) & (df_s08['Time'] <= end_time_4), 'Label'] = 1

df_s08.to_csv('S08_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s08 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S08/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s08), 4):
    avg = df_s08[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s08 = pd.DataFrame({'EDA': averages})
result_df_s08.to_csv('result_S08_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s08 = pd.read_csv('result_S08_EDA.csv')

start_time = 1644840744

df_s08['Time'] = [start_time + i for i in range(len(df_s08))]

df_s08.to_csv('S08_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s08 = pd.read_csv('S08_EDA.csv')

start_time_1 = 1644841379
end_time_1 = 1644841698
start_time_2 = 1644842006
end_time_2 = 1644842586
start_time_3 = 1644842880
end_time_3 = 1644842992
start_time_4 = 1644843281
end_time_4 = 1644843581

df_s08['Label'] = 0

df_s08.loc[(df_s08['Time'] >= start_time_1) & (df_s08['Time'] <= end_time_1), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_2) & (df_s08['Time'] <= end_time_2), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_3) & (df_s08['Time'] <= end_time_3), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_4) & (df_s08['Time'] <= end_time_4), 'Label'] = 1

df_s08.to_csv('S08_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s08 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S08/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s08), 4):
    avg = df_s08[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s08 = pd.DataFrame({'TEMP': averages})
result_df_s08.to_csv('result_S08_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s08 = pd.read_csv('result_S08_TEMP.csv')

start_time = 1644840744

df_s08['Time'] = [start_time + i for i in range(len(df_s08))]

df_s08.to_csv('S08_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s08 = pd.read_csv('S08_TEMP.csv')

start_time_1 = 1644841379
end_time_1 = 1644841698
start_time_2 = 1644842006
end_time_2 = 1644842586
start_time_3 = 1644842880
end_time_3 = 1644842992
start_time_4 = 1644843281
end_time_4 = 1644843581

df_s08['Label'] = 0

df_s08.loc[(df_s08['Time'] >= start_time_1) & (df_s08['Time'] <= end_time_1), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_2) & (df_s08['Time'] <= end_time_2), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_3) & (df_s08['Time'] <= end_time_3), 'Label'] = 1
df_s08.loc[(df_s08['Time'] >= start_time_4) & (df_s08['Time'] <= end_time_4), 'Label'] = 1

df_s08.to_csv('S08_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S08

# %%
df_HR = pd.read_csv('S08_HR_Label.csv')
df_BVP = pd.read_csv('S08_BVP_Label.csv')
df_EDA = pd.read_csv('S08_EDA_Label.csv')
df_TEMP = pd.read_csv('S08_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s08_merge = pd.merge(df_merge1, df_merge2)
df_s08_merge.to_csv('s08_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s09 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S09/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s09), 64):
    avg = df_s09[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s09 = pd.DataFrame({'BVP': averages})
result_df_s09.to_csv('result_S09_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s09 = pd.read_csv('result_S09_BVP.csv')

start_time = 1644842289

df_s09['Time'] = [start_time + i for i in range(len(df_s09))]

df_s09.to_csv('S09_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s09 = pd.read_csv('S09_BVP.csv')

start_time_1 = 1644842926
end_time_1 = 1644843250
start_time_2 = 1644843649
end_time_2 = 1644844144
start_time_3 = 1644844447
end_time_3 = 1644844587
start_time_4 = 1644844847
end_time_4 = 1644845147

df_s09['Label'] = 0

df_s09.loc[(df_s09['Time'] >= start_time_1) & (df_s09['Time'] <= end_time_1), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_2) & (df_s09['Time'] <= end_time_2), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_3) & (df_s09['Time'] <= end_time_3), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_4) & (df_s09['Time'] <= end_time_4), 'Label'] = 1

df_s09.to_csv('S09_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s09 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S09/HR.csv')
df_s09 = df_s09.iloc[1:]

start_time = 1644842299

df_s09['Time'] = [start_time + i for i in range(len(df_s09))]

df_s09.to_csv('S09_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s09 = pd.read_csv('S09_HR.csv')

start_time_1 = 1644842926
end_time_1 = 1644843250
start_time_2 = 1644843649
end_time_2 = 1644844144
start_time_3 = 1644844447
end_time_3 = 1644844587
start_time_4 = 1644844847
end_time_4 = 1644845147

df_s09['Label'] = 0

df_s09.loc[(df_s09['Time'] >= start_time_1) & (df_s09['Time'] <= end_time_1), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_2) & (df_s09['Time'] <= end_time_2), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_3) & (df_s09['Time'] <= end_time_3), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_4) & (df_s09['Time'] <= end_time_4), 'Label'] = 1

df_s09.to_csv('S09_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s09 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S09/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s09), 4):
    avg = df_s09[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s09 = pd.DataFrame({'EDA': averages})
result_df_s09.to_csv('result_S09_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s09 = pd.read_csv('result_S09_EDA.csv')

start_time = 1644842289

df_s09['Time'] = [start_time + i for i in range(len(df_s09))]

df_s09.to_csv('S09_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s09 = pd.read_csv('S09_EDA.csv')

start_time_1 = 1644842926
end_time_1 = 1644843250
start_time_2 = 1644843649
end_time_2 = 1644844144
start_time_3 = 1644844447
end_time_3 = 1644844587
start_time_4 = 1644844847
end_time_4 = 1644845147

df_s09['Label'] = 0

df_s09.loc[(df_s09['Time'] >= start_time_1) & (df_s09['Time'] <= end_time_1), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_2) & (df_s09['Time'] <= end_time_2), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_3) & (df_s09['Time'] <= end_time_3), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_4) & (df_s09['Time'] <= end_time_4), 'Label'] = 1

df_s09.to_csv('S09_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s09 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S09/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s09), 4):
    avg = df_s09[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s09 = pd.DataFrame({'TEMP': averages})
result_df_s09.to_csv('result_S09_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s09 = pd.read_csv('result_S09_TEMP.csv')

start_time = 1644842289

df_s09['Time'] = [start_time + i for i in range(len(df_s09))]

df_s09.to_csv('S09_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s09 = pd.read_csv('S09_TEMP.csv')

start_time_1 = 1644842926
end_time_1 = 1644843250
start_time_2 = 1644843649
end_time_2 = 1644844144
start_time_3 = 1644844447
end_time_3 = 1644844587
start_time_4 = 1644844847
end_time_4 = 1644845147

df_s09['Label'] = 0

df_s09.loc[(df_s09['Time'] >= start_time_1) & (df_s09['Time'] <= end_time_1), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_2) & (df_s09['Time'] <= end_time_2), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_3) & (df_s09['Time'] <= end_time_3), 'Label'] = 1
df_s09.loc[(df_s09['Time'] >= start_time_4) & (df_s09['Time'] <= end_time_4), 'Label'] = 1

df_s09.to_csv('S09_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S09

# %%
df_HR = pd.read_csv('S09_HR_Label.csv')
df_BVP = pd.read_csv('S09_BVP_Label.csv')
df_EDA = pd.read_csv('S09_EDA_Label.csv')
df_TEMP = pd.read_csv('S09_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s09_merge = pd.merge(df_merge1, df_merge2)
df_s09_merge.to_csv('s09_merge.csv', index=False)

# %% [markdown]
# Taking mean of 64 values and storing as a single value for a second as frequency is 64Hz

# %%
df_s10 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S10/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s10), 64):
    avg = df_s10[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s10 = pd.DataFrame({'BVP': averages})
result_df_s10.to_csv('result_S10_BVP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s10 = pd.read_csv('result_S10_BVP.csv')

start_time = 1644844459

df_s10['Time'] = [start_time + i for i in range(len(df_s10))]

df_s10.to_csv('S10_BVP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s10 = pd.read_csv('S10_BVP.csv')

start_time_1 = 1644845022
end_time_1 = 1644845324
start_time_2 = 1644845640
end_time_2 = 1644846207
start_time_3 = 1644846506 
end_time_3 = 1644846639
start_time_4 = 1644846944
end_time_4 = 1644847244

df_s10['Label'] = 0

df_s10.loc[(df_s10['Time'] >= start_time_1) & (df_s10['Time'] <= end_time_1), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_2) & (df_s10['Time'] <= end_time_2), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_3) & (df_s10['Time'] <= end_time_3), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_4) & (df_s10['Time'] <= end_time_4), 'Label'] = 1

df_s10.to_csv('S10_BVP_Label.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s10 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S10/HR.csv')
df_s10 = df_s10.iloc[1:]

start_time = 1644844469

df_s10['Time'] = [start_time + i for i in range(len(df_s10))]

df_s10.to_csv('S10_HR.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s10 = pd.read_csv('S10_HR.csv')

start_time_1 = 1644845022
end_time_1 = 1644845324
start_time_2 = 1644845640
end_time_2 = 1644846207
start_time_3 = 1644846506 
end_time_3 = 1644846639
start_time_4 = 1644846944
end_time_4 = 1644847244

df_s10['Label'] = 0

df_s10.loc[(df_s10['Time'] >= start_time_1) & (df_s10['Time'] <= end_time_1), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_2) & (df_s10['Time'] <= end_time_2), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_3) & (df_s10['Time'] <= end_time_3), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_4) & (df_s10['Time'] <= end_time_4), 'Label'] = 1

df_s10.to_csv('S10_HR_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s10 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S10/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s10), 4):
    avg = df_s10[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s10 = pd.DataFrame({'EDA': averages})
result_df_s10.to_csv('result_S10_EDA.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s10 = pd.read_csv('result_S10_EDA.csv')

start_time = 1644844459

df_s10['Time'] = [start_time + i for i in range(len(df_s10))]

df_s10.to_csv('S10_EDA.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s10 = pd.read_csv('S10_EDA.csv')

start_time_1 = 1644845022
end_time_1 = 1644845324
start_time_2 = 1644845640
end_time_2 = 1644846207
start_time_3 = 1644846506 
end_time_3 = 1644846639
start_time_4 = 1644846944
end_time_4 = 1644847244

df_s10['Label'] = 0

df_s10.loc[(df_s10['Time'] >= start_time_1) & (df_s10['Time'] <= end_time_1), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_2) & (df_s10['Time'] <= end_time_2), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_3) & (df_s10['Time'] <= end_time_3), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_4) & (df_s10['Time'] <= end_time_4), 'Label'] = 1

df_s10.to_csv('S10_EDA_Label.csv', index=False)

# %% [markdown]
# Taking mean of 4 values and storing as a single value for a second as frequency is 4Hz

# %%
df_s10 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S10/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s10), 4):
    avg = df_s10[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s10 = pd.DataFrame({'TEMP': averages})
result_df_s10.to_csv('result_S10_TEMP.csv', index=False)

# %% [markdown]
# Adding Time column to a csv file

# %%
df_s10 = pd.read_csv('result_S10_TEMP.csv')

start_time = 1644844459

df_s10['Time'] = [start_time + i for i in range(len(df_s10))]

df_s10.to_csv('S10_TEMP.csv', index=False)

# %% [markdown]
# Adding labels to the values in a csv file

# %%
df_s10 = pd.read_csv('S10_TEMP.csv')

start_time_1 = 1644845022
end_time_1 = 1644845324
start_time_2 = 1644845640
end_time_2 = 1644846207
start_time_3 = 1644846506 
end_time_3 = 1644846639
start_time_4 = 1644846944
end_time_4 = 1644847244

df_s10['Label'] = 0

df_s10.loc[(df_s10['Time'] >= start_time_1) & (df_s10['Time'] <= end_time_1), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_2) & (df_s10['Time'] <= end_time_2), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_3) & (df_s10['Time'] <= end_time_3), 'Label'] = 1
df_s10.loc[(df_s10['Time'] >= start_time_4) & (df_s10['Time'] <= end_time_4), 'Label'] = 1

df_s10.to_csv('S10_TEMP_Label.csv', index=False)

# %% [markdown]
# Merging HR,BVP,EDA and TEMP data of S10

# %%
df_HR = pd.read_csv('S10_HR_Label.csv')
df_BVP = pd.read_csv('S10_BVP_Label.csv')
df_EDA = pd.read_csv('S10_EDA_Label.csv')
df_TEMP = pd.read_csv('S10_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s10_merge = pd.merge(df_merge1, df_merge2)
df_s10_merge.to_csv('s10_merge.csv', index=False)

# %%
df_s11 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S11/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s11), 64):
    avg = df_s11[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s11 = pd.DataFrame({'BVP': averages})
result_df_s11.to_csv('result_S11_BVP.csv', index=False)

# %%
df_s11 = pd.read_csv('result_S11_BVP.csv')

start_time = 1644852028

df_s11['Time'] = [start_time + i for i in range(len(df_s11))]

df_s11.to_csv('S11_BVP.csv', index=False)

# %%
df_s11 = pd.read_csv('S11_BVP.csv')

start_time_1 = 1644852661
end_time_1 = 1644853067
start_time_2 = 1644853353
end_time_2 = 1644853978
start_time_3 = 1644854293
end_time_3 = 1644854446
start_time_4 = 1644854744
end_time_4 = 1644854984


df_s11['Label'] = 0

df_s11.loc[(df_s11['Time'] >= start_time_1) & (df_s11['Time'] <= end_time_1), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_2) & (df_s11['Time'] <= end_time_2), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_3) & (df_s11['Time'] <= end_time_3), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_4) & (df_s11['Time'] <= end_time_4), 'Label'] = 1

df_s11.to_csv('S11_BVP_Label.csv', index=False)

# %%
df_s11 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S11/HR.csv')
df_s11 = df_s11.iloc[1:]

start_time = 1644852038

df_s11['Time'] = [start_time + i for i in range(len(df_s11))]

df_s11.to_csv('S11_HR.csv', index=False)

# %%
df_s11 = pd.read_csv('S11_HR.csv')

start_time_1 = 1644852661
end_time_1 = 1644853067
start_time_2 = 1644853353
end_time_2 = 1644853978
start_time_3 = 1644854293
end_time_3 = 1644854446
start_time_4 = 1644854744
end_time_4 = 1644854984

df_s11['Label'] = 0

df_s11.loc[(df_s11['Time'] >= start_time_1) & (df_s11['Time'] <= end_time_1), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_2) & (df_s11['Time'] <= end_time_2), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_3) & (df_s11['Time'] <= end_time_3), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_4) & (df_s11['Time'] <= end_time_4), 'Label'] = 1

df_s11.to_csv('S11_HR_Label.csv', index=False)

# %%
df_s11 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S11/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s11), 4):
    avg = df_s11[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s11 = pd.DataFrame({'EDA': averages})
result_df_s11.to_csv('result_S11_EDA.csv', index=False)

# %%
df_s11 = pd.read_csv('result_S11_EDA.csv')

start_time = 1644852028

df_s11['Time'] = [start_time + i for i in range(len(df_s11))]

df_s11.to_csv('S11_EDA.csv', index=False)

# %%
df_s11 = pd.read_csv('S11_EDA.csv')

start_time_1 = 1644852661
end_time_1 = 1644853067
start_time_2 = 1644853353
end_time_2 = 1644853978
start_time_3 = 1644854293
end_time_3 = 1644854446
start_time_4 = 1644854744
end_time_4 = 1644854984

df_s11['Label'] = 0

df_s11.loc[(df_s11['Time'] >= start_time_1) & (df_s11['Time'] <= end_time_1), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_2) & (df_s11['Time'] <= end_time_2), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_3) & (df_s11['Time'] <= end_time_3), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_4) & (df_s11['Time'] <= end_time_4), 'Label'] = 1

df_s11.to_csv('S11_EDA_Label.csv', index=False)

# %%
df_s11 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S11/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s11), 4):
    avg = df_s11[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s11 = pd.DataFrame({'TEMP': averages})
result_df_s11.to_csv('result_S11_TEMP.csv', index=False)

# %%
df_s11 = pd.read_csv('result_S11_TEMP.csv')

start_time = 1644852028

df_s11['Time'] = [start_time + i for i in range(len(df_s11))]

df_s11.to_csv('S11_TEMP.csv', index=False)

# %%
df_s11 = pd.read_csv('S11_TEMP.csv')

start_time_1 = 1644852661
end_time_1 = 1644853067
start_time_2 = 1644853353
end_time_2 = 1644853978
start_time_3 = 1644854293
end_time_3 = 1644854446
start_time_4 = 1644854744
end_time_4 = 1644854984

df_s11['Label'] = 0

df_s11.loc[(df_s11['Time'] >= start_time_1) & (df_s11['Time'] <= end_time_1), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_2) & (df_s11['Time'] <= end_time_2), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_3) & (df_s11['Time'] <= end_time_3), 'Label'] = 1
df_s11.loc[(df_s11['Time'] >= start_time_4) & (df_s11['Time'] <= end_time_4), 'Label'] = 1

df_s11.to_csv('S11_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S11_HR_Label.csv')
df_BVP = pd.read_csv('S11_BVP_Label.csv')
df_EDA = pd.read_csv('S11_EDA_Label.csv')
df_TEMP = pd.read_csv('S11_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s11_merge = pd.merge(df_merge1, df_merge2)
df_s11_merge.to_csv('s11_merge.csv', index=False)

# %%
df_s12 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S12/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s12), 64):
    avg = df_s12[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s12 = pd.DataFrame({'BVP': averages})
result_df_s12.to_csv('result_S12_BVP.csv', index=False)

# %%
df_s12 = pd.read_csv('result_S12_BVP.csv')

start_time = 1645434908

df_s12['Time'] = [start_time + i for i in range(len(df_s12))]

df_s12.to_csv('S12_BVP.csv', index=False)

# %%
df_s12 = pd.read_csv('S12_BVP.csv')

start_time_1 = 1645435586
end_time_1 = 1645435914
start_time_2 = 1645436255
end_time_2 = 1645436906
start_time_3 = 1645437186
end_time_3 = 1645437313
start_time_4 = 1645437611
end_time_4 = 1645437911

df_s12['Label'] = 0

df_s12.loc[(df_s12['Time'] >= start_time_1) & (df_s12['Time'] <= end_time_1), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_2) & (df_s12['Time'] <= end_time_2), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_3) & (df_s12['Time'] <= end_time_3), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_4) & (df_s12['Time'] <= end_time_4), 'Label'] = 1

df_s12.to_csv('S12_BVP_Label.csv', index=False)

# %%
df_s12 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S12/HR.csv')
df_s12 = df_s12.iloc[1:]

start_time = 1645434918

df_s12['Time'] = [start_time + i for i in range(len(df_s12))]

df_s12.to_csv('S12_HR.csv', index=False)

# %%
df_s12 = pd.read_csv('S12_HR.csv')

start_time_1 = 1645435586
end_time_1 = 1645435914
start_time_2 = 1645436255
end_time_2 = 1645436906
start_time_3 = 1645437186
end_time_3 = 1645437313
start_time_4 = 1645437611
end_time_4 = 1645437911 

df_s12['Label'] = 0

df_s12.loc[(df_s12['Time'] >= start_time_1) & (df_s12['Time'] <= end_time_1), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_2) & (df_s12['Time'] <= end_time_2), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_3) & (df_s12['Time'] <= end_time_3), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_4) & (df_s12['Time'] <= end_time_4), 'Label'] = 1

df_s12.to_csv('S12_HR_Label.csv', index=False)

# %%
df_s12 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S12/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s12), 4):
    avg = df_s12[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s12 = pd.DataFrame({'EDA': averages})
result_df_s12.to_csv('result_S12_EDA.csv', index=False)

# %%
df_s12 = pd.read_csv('result_S12_EDA.csv')

start_time = 1645434908

df_s12['Time'] = [start_time + i for i in range(len(df_s12))]

df_s12.to_csv('S12_EDA.csv', index=False)

# %%
df_s12 = pd.read_csv('S12_EDA.csv')

start_time_1 = 1645435586
end_time_1 = 1645435914
start_time_2 = 1645436255
end_time_2 = 1645436906
start_time_3 = 1645437186
end_time_3 = 1645437313
start_time_4 = 1645437611
end_time_4 = 1645437911 

df_s12['Label'] = 0

df_s12.loc[(df_s12['Time'] >= start_time_1) & (df_s12['Time'] <= end_time_1), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_2) & (df_s12['Time'] <= end_time_2), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_3) & (df_s12['Time'] <= end_time_3), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_4) & (df_s12['Time'] <= end_time_4), 'Label'] = 1

df_s12.to_csv('S12_EDA_Label.csv', index=False)

# %%
df_s12 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S12/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s12), 4):
    avg = df_s12[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s12 = pd.DataFrame({'TEMP': averages})
result_df_s12.to_csv('result_S12_TEMP.csv', index=False)

# %%
df_s12 = pd.read_csv('result_S12_TEMP.csv')

start_time = 1645434908

df_s12['Time'] = [start_time + i for i in range(len(df_s12))]

df_s12.to_csv('S12_TEMP.csv', index=False)

# %%
df_s12 = pd.read_csv('S12_TEMP.csv')

start_time_1 = 1645435586
end_time_1 = 1645435914
start_time_2 = 1645436255
end_time_2 = 1645436906
start_time_3 = 1645437186
end_time_3 = 1645437313
start_time_4 = 1645437611
end_time_4 = 1645437911 

df_s12['Label'] = 0

df_s12.loc[(df_s12['Time'] >= start_time_1) & (df_s12['Time'] <= end_time_1), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_2) & (df_s12['Time'] <= end_time_2), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_3) & (df_s12['Time'] <= end_time_3), 'Label'] = 1
df_s12.loc[(df_s12['Time'] >= start_time_4) & (df_s12['Time'] <= end_time_4), 'Label'] = 1

df_s12.to_csv('S12_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S12_HR_Label.csv')
df_BVP = pd.read_csv('S12_BVP_Label.csv')
df_EDA = pd.read_csv('S12_EDA_Label.csv')
df_TEMP = pd.read_csv('S12_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s12_merge = pd.merge(df_merge1, df_merge2)
df_s12_merge.to_csv('s12_merge.csv', index=False)

# %%
df_s13 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S13/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s13), 64):
    avg = df_s13[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s13 = pd.DataFrame({'BVP': averages})
result_df_s13.to_csv('result_S13_BVP.csv', index=False)

# %%
df_s13 = pd.read_csv('result_S13_BVP.csv')

start_time = 1645442647

df_s13['Time'] = [start_time + i for i in range(len(df_s13))]

df_s13.to_csv('S13_BVP.csv', index=False)

# %%
df_s13 = pd.read_csv('S13_BVP.csv')

start_time_1 = 1645443300
end_time_1 = 1645443734
start_time_2 = 1645444043
end_time_2 = 1645444670
start_time_3 = 1645444972
end_time_3 = 1645445078
start_time_4 = 1645445400
end_time_4 = 1645445640


df_s13['Label'] = 0

df_s13.loc[(df_s13['Time'] >= start_time_1) & (df_s13['Time'] <= end_time_1), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_2) & (df_s13['Time'] <= end_time_2), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_3) & (df_s13['Time'] <= end_time_3), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_4) & (df_s13['Time'] <= end_time_4), 'Label'] = 1

df_s13.to_csv('S13_BVP_Label.csv', index=False)

# %%
df_s13 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S13/HR.csv')
df_s13 = df_s13.iloc[1:]

start_time = 1645442657

df_s13['Time'] = [start_time + i for i in range(len(df_s13))]

df_s13.to_csv('S13_HR.csv', index=False)

# %%
df_s13 = pd.read_csv('S13_HR.csv')

start_time_1 = 1645443300
end_time_1 = 1645443734
start_time_2 = 1645444043
end_time_2 = 1645444670
start_time_3 = 1645444972
end_time_3 = 1645445078
start_time_4 = 1645445400
end_time_4 = 1645445640 

df_s13['Label'] = 0

df_s13.loc[(df_s13['Time'] >= start_time_1) & (df_s13['Time'] <= end_time_1), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_2) & (df_s13['Time'] <= end_time_2), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_3) & (df_s13['Time'] <= end_time_3), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_4) & (df_s13['Time'] <= end_time_4), 'Label'] = 1

df_s13.to_csv('S13_HR_Label.csv', index=False)

# %%
df_s13 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S13/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s13), 4):
    avg = df_s13[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s13 = pd.DataFrame({'EDA': averages})
result_df_s13.to_csv('result_S13_EDA.csv', index=False)

# %%
df_s13 = pd.read_csv('result_S13_EDA.csv')

start_time = 1645442647

df_s13['Time'] = [start_time + i for i in range(len(df_s13))]

df_s13.to_csv('S13_EDA.csv', index=False)

# %%
df_s13 = pd.read_csv('S13_EDA.csv')

start_time_1 = 1645443300
end_time_1 = 1645443734
start_time_2 = 1645444043
end_time_2 = 1645444670
start_time_3 = 1645444972
end_time_3 = 1645445078
start_time_4 = 1645445400
end_time_4 = 1645445640 

df_s13['Label'] = 0

df_s13.loc[(df_s13['Time'] >= start_time_1) & (df_s13['Time'] <= end_time_1), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_2) & (df_s13['Time'] <= end_time_2), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_3) & (df_s13['Time'] <= end_time_3), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_4) & (df_s13['Time'] <= end_time_4), 'Label'] = 1

df_s13.to_csv('S13_EDA_Label.csv', index=False)

# %%
df_s13 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S13/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s13), 4):
    avg = df_s13[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s13 = pd.DataFrame({'TEMP': averages})
result_df_s13.to_csv('result_S13_TEMP.csv', index=False)

# %%
df_s13 = pd.read_csv('result_S13_TEMP.csv')

start_time = 1645442647

df_s13['Time'] = [start_time + i for i in range(len(df_s13))]

df_s13.to_csv('S13_TEMP.csv', index=False)

# %%
df_s13 = pd.read_csv('S13_TEMP.csv')

start_time_1 = 1645443300
end_time_1 = 1645443734
start_time_2 = 1645444043
end_time_2 = 1645444670
start_time_3 = 1645444972
end_time_3 = 1645445078
start_time_4 = 1645445400
end_time_4 = 1645445640 

df_s13['Label'] = 0

df_s13.loc[(df_s13['Time'] >= start_time_1) & (df_s13['Time'] <= end_time_1), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_2) & (df_s13['Time'] <= end_time_2), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_3) & (df_s13['Time'] <= end_time_3), 'Label'] = 1
df_s13.loc[(df_s13['Time'] >= start_time_4) & (df_s13['Time'] <= end_time_4), 'Label'] = 1

df_s13.to_csv('S13_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S13_HR_Label.csv')
df_BVP = pd.read_csv('S13_BVP_Label.csv')
df_EDA = pd.read_csv('S13_EDA_Label.csv')
df_TEMP = pd.read_csv('S13_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s13_merge = pd.merge(df_merge1, df_merge2)
df_s13_merge.to_csv('s13_merge.csv', index=False)

# %%
df_s14 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S14/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s14), 64):
    avg = df_s14[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s14 = pd.DataFrame({'BVP': averages})
result_df_s14.to_csv('result_S14_BVP.csv', index=False)

# %%
df_s14 = pd.read_csv('result_S14_BVP.csv')

start_time = 1645444063

df_s14['Time'] = [start_time + i for i in range(len(df_s14))]

df_s14.to_csv('S14_BVP.csv', index=False)

# %%
df_s14 = pd.read_csv('S14_BVP.csv')

start_time_1 = 1645444763
end_time_1 = 1645445148
start_time_2 = 1645445449
end_time_2 = 1645446106
start_time_3 = 1645446512
end_time_3 = 1645446650
start_time_4 = 1645446833
end_time_4 = 1645447333

df_s14['Label'] = 0

df_s14.loc[(df_s14['Time'] >= start_time_1) & (df_s14['Time'] <= end_time_1), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_2) & (df_s14['Time'] <= end_time_2), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_3) & (df_s14['Time'] <= end_time_3), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_4) & (df_s14['Time'] <= end_time_4), 'Label'] = 1

df_s14.to_csv('S14_BVP_Label.csv', index=False)

# %%
df_s14 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S14/HR.csv')
df_s14 = df_s14.iloc[1:]

start_time = 1645444073

df_s14['Time'] = [start_time + i for i in range(len(df_s14))]

df_s14.to_csv('S14_HR.csv', index=False)

# %%
df_s14 = pd.read_csv('S14_HR.csv')

start_time_1 = 1645444763
end_time_1 = 1645445148
start_time_2 = 1645445449
end_time_2 = 1645446106
start_time_3 = 1645446512
end_time_3 = 1645446650
start_time_4 = 1645446833
end_time_4 = 1645447333 

df_s14['Label'] = 0

df_s14.loc[(df_s14['Time'] >= start_time_1) & (df_s14['Time'] <= end_time_1), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_2) & (df_s14['Time'] <= end_time_2), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_3) & (df_s14['Time'] <= end_time_3), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_4) & (df_s14['Time'] <= end_time_4), 'Label'] = 1

df_s14.to_csv('S14_HR_Label.csv', index=False)

# %%
df_s14 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S14/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s14), 4):
    avg = df_s14[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s14 = pd.DataFrame({'EDA': averages})
result_df_s14.to_csv('result_S14_EDA.csv', index=False)

# %%
df_s14 = pd.read_csv('result_S14_EDA.csv')

start_time = 1645444063

df_s14['Time'] = [start_time + i for i in range(len(df_s14))]

df_s14.to_csv('S14_EDA.csv', index=False)

# %%
df_s14 = pd.read_csv('S14_EDA.csv')

start_time_1 = 1645444763
end_time_1 = 1645445148
start_time_2 = 1645445449
end_time_2 = 1645446106
start_time_3 = 1645446512
end_time_3 = 1645446650
start_time_4 = 1645446833
end_time_4 = 1645447333 

df_s14['Label'] = 0

df_s14.loc[(df_s14['Time'] >= start_time_1) & (df_s14['Time'] <= end_time_1), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_2) & (df_s14['Time'] <= end_time_2), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_3) & (df_s14['Time'] <= end_time_3), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_4) & (df_s14['Time'] <= end_time_4), 'Label'] = 1

df_s14.to_csv('S14_EDA_Label.csv', index=False)

# %%
df_s14 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S14/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s14), 4):
    avg = df_s14[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s14 = pd.DataFrame({'TEMP': averages})
result_df_s14.to_csv('result_S14_TEMP.csv', index=False)

# %%
df_s14 = pd.read_csv('result_S14_TEMP.csv')

start_time = 1645444063

df_s14['Time'] = [start_time + i for i in range(len(df_s14))]

df_s14.to_csv('S14_TEMP.csv', index=False)

# %%
df_s14 = pd.read_csv('S14_TEMP.csv')

start_time_1 = 1645444763
end_time_1 = 1645445148
start_time_2 = 1645445449
end_time_2 = 1645446106
start_time_3 = 1645446512
end_time_3 = 1645446650
start_time_4 = 1645446833
end_time_4 = 1645447333 

df_s14['Label'] = 0

df_s14.loc[(df_s14['Time'] >= start_time_1) & (df_s14['Time'] <= end_time_1), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_2) & (df_s14['Time'] <= end_time_2), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_3) & (df_s14['Time'] <= end_time_3), 'Label'] = 1
df_s14.loc[(df_s14['Time'] >= start_time_4) & (df_s14['Time'] <= end_time_4), 'Label'] = 1

df_s14.to_csv('S14_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S14_HR_Label.csv')
df_BVP = pd.read_csv('S14_BVP_Label.csv')
df_EDA = pd.read_csv('S14_EDA_Label.csv')
df_TEMP = pd.read_csv('S14_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s14_merge = pd.merge(df_merge1, df_merge2)
df_s14_merge.to_csv('s14_merge.csv', index=False)

# %%
df_s15 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S15/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s15), 64):
    avg = df_s15[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s15 = pd.DataFrame({'BVP': averages})
result_df_s15.to_csv('result_S15_BVP.csv', index=False)

# %%
df_s15 = pd.read_csv('result_S15_BVP.csv')

start_time = 1645446989

df_s15['Time'] = [start_time + i for i in range(len(df_s15))]

df_s15.to_csv('S15_BVP.csv', index=False)

# %%
df_s15 = pd.read_csv('S15_BVP.csv')

start_time_1 = 1645447787
end_time_1 = 1645448070
start_time_2 = 1645448401
end_time_2 = 1645449083
start_time_3 = 1645449392
end_time_3 = 1645449533
start_time_4 = 1645449850
end_time_4 = 1645450150

df_s15['Label'] = 0

df_s15.loc[(df_s15['Time'] >= start_time_1) & (df_s15['Time'] <= end_time_1), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_2) & (df_s15['Time'] <= end_time_2), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_3) & (df_s15['Time'] <= end_time_3), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_4) & (df_s15['Time'] <= end_time_4), 'Label'] = 1

df_s15.to_csv('S15_BVP_Label.csv', index=False)

# %%
df_s15 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S15/HR.csv')
df_s15 = df_s15.iloc[1:]

start_time = 1645446999

df_s15['Time'] = [start_time + i for i in range(len(df_s15))]

df_s15.to_csv('S15_HR.csv', index=False)

# %%
df_s15 = pd.read_csv('S15_HR.csv')

start_time_1 = 1645447787
end_time_1 = 1645448070
start_time_2 = 1645448401
end_time_2 = 1645449083
start_time_3 = 1645449392
end_time_3 = 1645449533
start_time_4 = 1645449850
end_time_4 = 1645450150

df_s15['Label'] = 0

df_s15.loc[(df_s15['Time'] >= start_time_1) & (df_s15['Time'] <= end_time_1), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_2) & (df_s15['Time'] <= end_time_2), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_3) & (df_s15['Time'] <= end_time_3), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_4) & (df_s15['Time'] <= end_time_4), 'Label'] = 1

df_s15.to_csv('S15_HR_Label.csv', index=False)

# %%
df_s15 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S15/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s15), 4):
    avg = df_s15[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s15 = pd.DataFrame({'EDA': averages})
result_df_s15.to_csv('result_S15_EDA.csv', index=False)

# %%
df_s15 = pd.read_csv('result_S15_EDA.csv')

start_time = 1645446989

df_s15['Time'] = [start_time + i for i in range(len(df_s15))]

df_s15.to_csv('S15_EDA.csv', index=False)

# %%
df_s15 = pd.read_csv('S15_EDA.csv')

start_time_1 = 1645447787
end_time_1 = 1645448070
start_time_2 = 1645448401
end_time_2 = 1645449083
start_time_3 = 1645449392
end_time_3 = 1645449533
start_time_4 = 1645449850
end_time_4 = 1645450150

df_s15['Label'] = 0

df_s15.loc[(df_s15['Time'] >= start_time_1) & (df_s15['Time'] <= end_time_1), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_2) & (df_s15['Time'] <= end_time_2), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_3) & (df_s15['Time'] <= end_time_3), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_4) & (df_s15['Time'] <= end_time_4), 'Label'] = 1

df_s15.to_csv('S15_EDA_Label.csv', index=False)

# %%
df_s15 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S15/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s15), 4):
    avg = df_s15[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s15 = pd.DataFrame({'TEMP': averages})
result_df_s15.to_csv('result_S15_TEMP.csv', index=False)

# %%
df_s15 = pd.read_csv('result_S15_TEMP.csv')

start_time = 1645446989

df_s15['Time'] = [start_time + i for i in range(len(df_s15))]

df_s15.to_csv('S15_TEMP.csv', index=False)

# %%
df_s15 = pd.read_csv('S15_TEMP.csv')

start_time_1 = 1645447787
end_time_1 = 1645448070
start_time_2 = 1645448401
end_time_2 = 1645449083
start_time_3 = 1645449392
end_time_3 = 1645449533
start_time_4 = 1645449850
end_time_4 = 1645450150

df_s15['Label'] = 0

df_s15.loc[(df_s15['Time'] >= start_time_1) & (df_s15['Time'] <= end_time_1), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_2) & (df_s15['Time'] <= end_time_2), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_3) & (df_s15['Time'] <= end_time_3), 'Label'] = 1
df_s15.loc[(df_s15['Time'] >= start_time_4) & (df_s15['Time'] <= end_time_4), 'Label'] = 1

df_s15.to_csv('S15_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S15_HR_Label.csv')
df_BVP = pd.read_csv('S15_BVP_Label.csv')
df_EDA = pd.read_csv('S15_EDA_Label.csv')
df_TEMP = pd.read_csv('S15_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s15_merge = pd.merge(df_merge1, df_merge2)
df_s15_merge.to_csv('s15_merge.csv', index=False)

# %%
df_s16 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S16/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s16), 64):
    avg = df_s16[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s16 = pd.DataFrame({'BVP': averages})
result_df_s16.to_csv('result_S16_BVP.csv', index=False)

# %%
df_s16 = pd.read_csv('result_S16_BVP.csv')

start_time = 1645449146

df_s16['Time'] = [start_time + i for i in range(len(df_s16))]

df_s16.to_csv('S16_BVP.csv', index=False)

# %%
df_s16 = pd.read_csv('S16_BVP.csv')

start_time_1 = 1645449931
end_time_1 = 1645450271
start_time_2 = 1645450612
end_time_2 = 1645451162
start_time_3 = 1645451498
end_time_3 = 1645451620
start_time_4 = 1645451974
end_time_4 = 1645452394


df_s16['Label'] = 0

df_s16.loc[(df_s16['Time'] >= start_time_1) & (df_s16['Time'] <= end_time_1), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_2) & (df_s16['Time'] <= end_time_2), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_3) & (df_s16['Time'] <= end_time_3), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_4) & (df_s16['Time'] <= end_time_4), 'Label'] = 1

df_s16.to_csv('S16_BVP_Label.csv', index=False)

# %%
df_s16 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S16/HR.csv')
df_s16 = df_s16.iloc[1:]

start_time = 1645449156

df_s16['Time'] = [start_time + i for i in range(len(df_s16))]

df_s16.to_csv('S16_HR.csv', index=False)

# %%
df_s16 = pd.read_csv('S16_HR.csv')

start_time_1 = 1645449931
end_time_1 = 1645450271
start_time_2 = 1645450612
end_time_2 = 1645451162
start_time_3 = 1645451498
end_time_3 = 1645451620
start_time_4 = 1645451974
end_time_4 = 1645452394

df_s16['Label'] = 0

df_s16.loc[(df_s16['Time'] >= start_time_1) & (df_s16['Time'] <= end_time_1), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_2) & (df_s16['Time'] <= end_time_2), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_3) & (df_s16['Time'] <= end_time_3), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_4) & (df_s16['Time'] <= end_time_4), 'Label'] = 1

df_s16.to_csv('S16_HR_Label.csv', index=False)

# %%
df_s16 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S16/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s16), 4):
    avg = df_s16[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s16 = pd.DataFrame({'EDA': averages})
result_df_s16.to_csv('result_S16_EDA.csv', index=False)

# %%
df_s16 = pd.read_csv('result_S16_EDA.csv')

start_time = 1645449146

df_s16['Time'] = [start_time + i for i in range(len(df_s16))]

df_s16.to_csv('S16_EDA.csv', index=False)

# %%
df_s16 = pd.read_csv('S16_EDA.csv')

start_time_1 = 1645449931
end_time_1 = 1645450271
start_time_2 = 1645450612
end_time_2 = 1645451162
start_time_3 = 1645451498
end_time_3 = 1645451620
start_time_4 = 1645451974
end_time_4 = 1645452394

df_s16['Label'] = 0

df_s16.loc[(df_s16['Time'] >= start_time_1) & (df_s16['Time'] <= end_time_1), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_2) & (df_s16['Time'] <= end_time_2), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_3) & (df_s16['Time'] <= end_time_3), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_4) & (df_s16['Time'] <= end_time_4), 'Label'] = 1

df_s16.to_csv('S16_EDA_Label.csv', index=False)

# %%
df_s16 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S16/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s16), 4):
    avg = df_s16[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s16 = pd.DataFrame({'TEMP': averages})
result_df_s16.to_csv('result_S16_TEMP.csv', index=False)

# %%
df_s16 = pd.read_csv('result_S16_TEMP.csv')

start_time = 1645449146

df_s16['Time'] = [start_time + i for i in range(len(df_s16))]

df_s16.to_csv('S16_TEMP.csv', index=False)

# %%
df_s16 = pd.read_csv('S16_TEMP.csv')

start_time_1 = 1645449931
end_time_1 = 1645450271
start_time_2 = 1645450612
end_time_2 = 1645451162
start_time_3 = 1645451498
end_time_3 = 1645451620
start_time_4 = 1645451974
end_time_4 = 1645452394

df_s16['Label'] = 0

df_s16.loc[(df_s16['Time'] >= start_time_1) & (df_s16['Time'] <= end_time_1), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_2) & (df_s16['Time'] <= end_time_2), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_3) & (df_s16['Time'] <= end_time_3), 'Label'] = 1
df_s16.loc[(df_s16['Time'] >= start_time_4) & (df_s16['Time'] <= end_time_4), 'Label'] = 1

df_s16.to_csv('S16_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S16_HR_Label.csv')
df_BVP = pd.read_csv('S16_BVP_Label.csv')
df_EDA = pd.read_csv('S16_EDA_Label.csv')
df_TEMP = pd.read_csv('S16_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s16_merge = pd.merge(df_merge1, df_merge2)
df_s16_merge.to_csv('s16_merge.csv', index=False)

# %%
df_s17 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S17/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s17), 64):
    avg = df_s17[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s17 = pd.DataFrame({'BVP': averages})
result_df_s17.to_csv('result_S17_BVP.csv', index=False)

# %%
df_s17 = pd.read_csv('result_S17_BVP.csv')

start_time = 1645456369

df_s17['Time'] = [start_time + i for i in range(len(df_s17))]

df_s17.to_csv('S17_BVP.csv', index=False)

# %%
df_s17 = pd.read_csv('S17_BVP.csv')

start_time_1 = 1645456965
end_time_1 = 1645457393
start_time_2 = 1645457730
end_time_2 = 1645415164
start_time_3 = 1645458708
end_time_3 = 1645458804
start_time_4 = 1645415944
end_time_4 = 1645416184

df_s17['Label'] = 0

df_s17.loc[(df_s17['Time'] >= start_time_1) & (df_s17['Time'] <= end_time_1), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_2) & (df_s17['Time'] <= end_time_2), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_3) & (df_s17['Time'] <= end_time_3), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_4) & (df_s17['Time'] <= end_time_4), 'Label'] = 1

df_s17.to_csv('S17_BVP_Label.csv', index=False)

# %%
df_s17 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S17/HR.csv')
df_s17 = df_s17.iloc[1:]

start_time = 1645456379

df_s17['Time'] = [start_time + i for i in range(len(df_s17))]

df_s17.to_csv('S17_HR.csv', index=False)

# %%
df_s17 = pd.read_csv('S17_HR.csv')

start_time_1 = 1645456965
end_time_1 = 1645457393
start_time_2 = 1645457730
end_time_2 = 1645415164
start_time_3 = 1645458708
end_time_3 = 1645458804
start_time_4 = 1645415944
end_time_4 = 1645416184

df_s17['Label'] = 0

df_s17.loc[(df_s17['Time'] >= start_time_1) & (df_s17['Time'] <= end_time_1), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_2) & (df_s17['Time'] <= end_time_2), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_3) & (df_s17['Time'] <= end_time_3), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_4) & (df_s17['Time'] <= end_time_4), 'Label'] = 1

df_s17.to_csv('S17_HR_Label.csv', index=False)

# %%
df_s17 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S17/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s17), 4):
    avg = df_s17[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s17 = pd.DataFrame({'EDA': averages})
result_df_s17.to_csv('result_S17_EDA.csv', index=False)

# %%
df_s17 = pd.read_csv('result_S17_EDA.csv')

start_time = 1645456369

df_s17['Time'] = [start_time + i for i in range(len(df_s17))]

df_s17.to_csv('S17_EDA.csv', index=False)

# %%
df_s17 = pd.read_csv('S17_EDA.csv')

start_time_1 = 1645456965
end_time_1 = 1645457393
start_time_2 = 1645457730
end_time_2 = 1645415164
start_time_3 = 1645458708
end_time_3 = 1645458804
start_time_4 = 1645415944
end_time_4 = 1645416184

df_s17['Label'] = 0

df_s17.loc[(df_s17['Time'] >= start_time_1) & (df_s17['Time'] <= end_time_1), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_2) & (df_s17['Time'] <= end_time_2), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_3) & (df_s17['Time'] <= end_time_3), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_4) & (df_s17['Time'] <= end_time_4), 'Label'] = 1

df_s17.to_csv('S17_EDA_Label.csv', index=False)

# %%
df_s17 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S17/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s17), 4):
    avg = df_s17[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s17 = pd.DataFrame({'TEMP': averages})
result_df_s17.to_csv('result_S17_TEMP.csv', index=False)

# %%
df_s17 = pd.read_csv('result_S17_TEMP.csv')

start_time = 1645456369

df_s17['Time'] = [start_time + i for i in range(len(df_s17))]

df_s17.to_csv('S17_TEMP.csv', index=False)

# %%
df_s17 = pd.read_csv('S17_TEMP.csv')

start_time_1 = 1645456965
end_time_1 = 1645457393
start_time_2 = 1645457730
end_time_2 = 1645415164
start_time_3 = 1645458708
end_time_3 = 1645458804
start_time_4 = 1645415944
end_time_4 = 1645416184

df_s17['Label'] = 0

df_s17.loc[(df_s17['Time'] >= start_time_1) & (df_s17['Time'] <= end_time_1), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_2) & (df_s17['Time'] <= end_time_2), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_3) & (df_s17['Time'] <= end_time_3), 'Label'] = 1
df_s17.loc[(df_s17['Time'] >= start_time_4) & (df_s17['Time'] <= end_time_4), 'Label'] = 1

df_s17.to_csv('S17_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S17_HR_Label.csv')
df_BVP = pd.read_csv('S17_BVP_Label.csv')
df_EDA = pd.read_csv('S17_EDA_Label.csv')
df_TEMP = pd.read_csv('S17_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s17_merge = pd.merge(df_merge1, df_merge2)
df_s17_merge.to_csv('s17_merge.csv', index=False)

# %%
df_s18 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S18/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s18), 64):
    avg = df_s18[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s18 = pd.DataFrame({'BVP': averages})
result_df_s18.to_csv('result_S18_BVP.csv', index=False)

# %%
df_s18 = pd.read_csv('result_S18_BVP.csv')

start_time = 1645457685

df_s18['Time'] = [start_time + i for i in range(len(df_s18))]

df_s18.to_csv('S18_BVP.csv', index=False)

# %%
df_s18 = pd.read_csv('S18_BVP.csv')

start_time_1 = 1645415164
end_time_1 = 1645458722
start_time_2 = 1645459067
end_time_2 = 1645459704
start_time_3 = 1645460019
end_time_3 = 1645460140
start_time_4 = 1645460440
end_time_4 = 1645460800

df_s18['Label'] = 0

df_s18.loc[(df_s18['Time'] >= start_time_1) & (df_s18['Time'] <= end_time_1), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_2) & (df_s18['Time'] <= end_time_2), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_3) & (df_s18['Time'] <= end_time_3), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_4) & (df_s18['Time'] <= end_time_4), 'Label'] = 1

df_s18.to_csv('S18_BVP_Label.csv', index=False)

# %%
df_s18 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S18/HR.csv')
df_s18 = df_s18.iloc[1:]

start_time = 1645457695

df_s18['Time'] = [start_time + i for i in range(len(df_s18))]

df_s18.to_csv('S18_HR.csv', index=False)

# %%
df_s18 = pd.read_csv('S18_HR.csv')

start_time_1 = 1645415164
end_time_1 = 1645458722
start_time_2 = 1645459067
end_time_2 = 1645459704
start_time_3 = 1645460019
end_time_3 = 1645460140
start_time_4 = 1645460440
end_time_4 = 1645460800

df_s18['Label'] = 0

df_s18.loc[(df_s18['Time'] >= start_time_1) & (df_s18['Time'] <= end_time_1), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_2) & (df_s18['Time'] <= end_time_2), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_3) & (df_s18['Time'] <= end_time_3), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_4) & (df_s18['Time'] <= end_time_4), 'Label'] = 1

df_s18.to_csv('S18_HR_Label.csv', index=False)

# %%
df_s18 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S18/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s18), 4):
    avg = df_s18[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s18 = pd.DataFrame({'EDA': averages})
result_df_s18.to_csv('result_S18_EDA.csv', index=False)

# %%
df_s18 = pd.read_csv('result_S18_EDA.csv')

start_time = 1645457685

df_s18['Time'] = [start_time + i for i in range(len(df_s18))]

df_s18.to_csv('S18_EDA.csv', index=False)

# %%
df_s18 = pd.read_csv('S18_EDA.csv')

start_time_1 = 1645415164
end_time_1 = 1645458722
start_time_2 = 1645459067
end_time_2 = 1645459704
start_time_3 = 1645460019
end_time_3 = 1645460140
start_time_4 = 1645460440
end_time_4 = 1645460800

df_s18['Label'] = 0

df_s18.loc[(df_s18['Time'] >= start_time_1) & (df_s18['Time'] <= end_time_1), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_2) & (df_s18['Time'] <= end_time_2), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_3) & (df_s18['Time'] <= end_time_3), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_4) & (df_s18['Time'] <= end_time_4), 'Label'] = 1

df_s18.to_csv('S18_EDA_Label.csv', index=False)

# %%
df_s18 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S18/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s18), 4):
    avg = df_s18[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s18 = pd.DataFrame({'TEMP': averages})
result_df_s18.to_csv('result_S18_TEMP.csv', index=False)

# %%
df_s18 = pd.read_csv('result_S18_TEMP.csv')

start_time = 1645457685

df_s18['Time'] = [start_time + i for i in range(len(df_s18))]

df_s18.to_csv('S18_TEMP.csv', index=False)

# %%
df_s18 = pd.read_csv('S18_TEMP.csv')

start_time_1 = 1645415164
end_time_1 = 1645458722
start_time_2 = 1645459067
end_time_2 = 1645459704
start_time_3 = 1645460019
end_time_3 = 1645460140
start_time_4 = 1645460440
end_time_4 = 1645460800

df_s18['Label'] = 0

df_s18.loc[(df_s18['Time'] >= start_time_1) & (df_s18['Time'] <= end_time_1), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_2) & (df_s18['Time'] <= end_time_2), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_3) & (df_s18['Time'] <= end_time_3), 'Label'] = 1
df_s18.loc[(df_s18['Time'] >= start_time_4) & (df_s18['Time'] <= end_time_4), 'Label'] = 1

df_s18.to_csv('S18_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S18_HR_Label.csv')
df_BVP = pd.read_csv('S18_BVP_Label.csv')
df_EDA = pd.read_csv('S18_EDA_Label.csv')
df_TEMP = pd.read_csv('S18_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s18_merge = pd.merge(df_merge1, df_merge2)
df_s18_merge.to_csv('s18_merge.csv', index=False)

# %%
df_s19 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S19/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s19), 64):
    avg = df_s19[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s19 = pd.DataFrame({'BVP': averages})
result_df_s19.to_csv('result_S19_BVP.csv', index=False)

# %%
df_s19 = pd.read_csv('result_S19_BVP.csv')

start_time = 1646039930

df_s19['Time'] = [start_time + i for i in range(len(df_s19))]

df_s19.to_csv('S19_BVP.csv', index=False)

# %%
df_s19 = pd.read_csv('S19_BVP.csv')

start_time_1 = 1646040534
end_time_1 = 1646040895
start_time_2 = 1646041363
end_time_2 = 1646041831
start_time_3 = 1646042113
end_time_3 = 1646042209
start_time_4 = 1646042509
end_time_4 = 1646042869


df_s19['Label'] = 0

df_s19.loc[(df_s19['Time'] >= start_time_1) & (df_s19['Time'] <= end_time_1), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_2) & (df_s19['Time'] <= end_time_2), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_3) & (df_s19['Time'] <= end_time_3), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_4) & (df_s19['Time'] <= end_time_4), 'Label'] = 1

df_s19.to_csv('S19_BVP_Label.csv', index=False)

# %%
df_s19 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S19/HR.csv')
df_s19 = df_s19.iloc[1:]

start_time = 1646039940

df_s19['Time'] = [start_time + i for i in range(len(df_s19))]

df_s19.to_csv('S19_HR.csv', index=False)

# %%
df_s19 = pd.read_csv('S19_HR.csv')

start_time_1 = 1646040534
end_time_1 = 1646040895
start_time_2 = 1646041363
end_time_2 = 1646041831
start_time_3 = 1646042113
end_time_3 = 1646042209
start_time_4 = 1646042509
end_time_4 = 1646042869 

df_s19['Label'] = 0

df_s19.loc[(df_s19['Time'] >= start_time_1) & (df_s19['Time'] <= end_time_1), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_2) & (df_s19['Time'] <= end_time_2), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_3) & (df_s19['Time'] <= end_time_3), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_4) & (df_s19['Time'] <= end_time_4), 'Label'] = 1

df_s19.to_csv('S19_HR_Label.csv', index=False)

# %%
df_s19 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S19/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s19), 4):
    avg = df_s19[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s19 = pd.DataFrame({'EDA': averages})
result_df_s19.to_csv('result_S19_EDA.csv', index=False)

# %%
df_s19 = pd.read_csv('result_S19_EDA.csv')

start_time = 1646039930

df_s19['Time'] = [start_time + i for i in range(len(df_s19))]

df_s19.to_csv('S19_EDA.csv', index=False)

# %%
df_s19 = pd.read_csv('S19_EDA.csv')

start_time_1 = 1646040534
end_time_1 = 1646040895
start_time_2 = 1646041363
end_time_2 = 1646041831
start_time_3 = 1646042113
end_time_3 = 1646042209
start_time_4 = 1646042509
end_time_4 = 1646042869 

df_s19['Label'] = 0

df_s19.loc[(df_s19['Time'] >= start_time_1) & (df_s19['Time'] <= end_time_1), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_2) & (df_s19['Time'] <= end_time_2), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_3) & (df_s19['Time'] <= end_time_3), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_4) & (df_s19['Time'] <= end_time_4), 'Label'] = 1

df_s19.to_csv('S19_EDA_Label.csv', index=False)

# %%
df_s19 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S19/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s19), 4):
    avg = df_s19[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s19 = pd.DataFrame({'TEMP': averages})
result_df_s19.to_csv('result_S19_TEMP.csv', index=False)

# %%
df_s19 = pd.read_csv('result_S19_TEMP.csv')

start_time = 1646039930

df_s19['Time'] = [start_time + i for i in range(len(df_s19))]

df_s19.to_csv('S19_TEMP.csv', index=False)

# %%
df_s19 = pd.read_csv('S19_TEMP.csv')

start_time_1 = 1646040534
end_time_1 = 1646040895
start_time_2 = 1646041363
end_time_2 = 1646041831
start_time_3 = 1646042113
end_time_3 = 1646042209
start_time_4 = 1646042509
end_time_4 = 1646042869 

df_s19['Label'] = 0

df_s19.loc[(df_s19['Time'] >= start_time_1) & (df_s19['Time'] <= end_time_1), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_2) & (df_s19['Time'] <= end_time_2), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_3) & (df_s19['Time'] <= end_time_3), 'Label'] = 1
df_s19.loc[(df_s19['Time'] >= start_time_4) & (df_s19['Time'] <= end_time_4), 'Label'] = 1

df_s19.to_csv('S19_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S19_HR_Label.csv')
df_BVP = pd.read_csv('S19_BVP_Label.csv')
df_EDA = pd.read_csv('S19_EDA_Label.csv')
df_TEMP = pd.read_csv('S19_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s19_merge = pd.merge(df_merge1, df_merge2)
df_s19_merge.to_csv('s19_merge.csv', index=False)

# %%
df_s20 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S20/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s20), 64):
    avg = df_s20[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s20 = pd.DataFrame({'BVP': averages})
result_df_s20.to_csv('result_S20_BVP.csv', index=False)

# %%
df_s20 = pd.read_csv('result_S20_BVP.csv')

start_time = 1646041789

df_s20['Time'] = [start_time + i for i in range(len(df_s20))]

df_s20.to_csv('S20_BVP.csv', index=False)

# %%
df_s20 = pd.read_csv('S20_BVP.csv')

start_time_1 = 1646042441
end_time_1 = 1646042792
start_time_2 = 1646043148
end_time_2 = 1646043735
start_time_3 = 1646044029
end_time_3 = 1646044136
start_time_4 = 1646044458
end_time_4 = 1646044758

df_s20['Label'] = 0

df_s20.loc[(df_s20['Time'] >= start_time_1) & (df_s20['Time'] <= end_time_1), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_2) & (df_s20['Time'] <= end_time_2), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_3) & (df_s20['Time'] <= end_time_3), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_4) & (df_s20['Time'] <= end_time_4), 'Label'] = 1

df_s20.to_csv('S20_BVP_Label.csv', index=False)

# %%
df_s20 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S20/HR.csv')
df_s20 = df_s20.iloc[1:]

start_time = 1646041799

df_s20['Time'] = [start_time + i for i in range(len(df_s20))]

df_s20.to_csv('S20_HR.csv', index=False)

# %%
df_s20 = pd.read_csv('S20_HR.csv')

start_time_1 = 1646042441
end_time_1 = 1646042792
start_time_2 = 1646043148
end_time_2 = 1646043735
start_time_3 = 1646044029
end_time_3 = 1646044136
start_time_4 = 1646044458
end_time_4 = 1646044758

df_s20['Label'] = 0

df_s20.loc[(df_s20['Time'] >= start_time_1) & (df_s20['Time'] <= end_time_1), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_2) & (df_s20['Time'] <= end_time_2), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_3) & (df_s20['Time'] <= end_time_3), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_4) & (df_s20['Time'] <= end_time_4), 'Label'] = 1

df_s20.to_csv('S20_HR_Label.csv', index=False)

# %%
df_s20 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S20/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s20), 4):
    avg = df_s20[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s20 = pd.DataFrame({'EDA': averages})
result_df_s20.to_csv('result_S20_EDA.csv', index=False)

# %%
df_s20 = pd.read_csv('result_S20_EDA.csv')

start_time = 1646041789

df_s20['Time'] = [start_time + i for i in range(len(df_s20))]

df_s20.to_csv('S20_EDA.csv', index=False)

# %%
df_s20 = pd.read_csv('S20_EDA.csv')

start_time_1 = 1646042441
end_time_1 = 1646042792
start_time_2 = 1646043148
end_time_2 = 1646043735
start_time_3 = 1646044029
end_time_3 = 1646044136
start_time_4 = 1646044458
end_time_4 = 1646044758

df_s20['Label'] = 0

df_s20.loc[(df_s20['Time'] >= start_time_1) & (df_s20['Time'] <= end_time_1), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_2) & (df_s20['Time'] <= end_time_2), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_3) & (df_s20['Time'] <= end_time_3), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_4) & (df_s20['Time'] <= end_time_4), 'Label'] = 1

df_s20.to_csv('S20_EDA_Label.csv', index=False)

# %%
df_s20 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S20/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s20), 4):
    avg = df_s20[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s20 = pd.DataFrame({'TEMP': averages})
result_df_s20.to_csv('result_S20_TEMP.csv', index=False)

# %%
df_s20 = pd.read_csv('result_S20_TEMP.csv')

start_time = 1646041789

df_s20['Time'] = [start_time + i for i in range(len(df_s20))]

df_s20.to_csv('S20_TEMP.csv', index=False)

# %%
df_s20 = pd.read_csv('S20_TEMP.csv')

start_time_1 = 1646042441
end_time_1 = 1646042792
start_time_2 = 1646043148
end_time_2 = 1646043735
start_time_3 = 1646044029
end_time_3 = 1646044136
start_time_4 = 1646044458
end_time_4 = 1646044758

df_s20['Label'] = 0

df_s20.loc[(df_s20['Time'] >= start_time_1) & (df_s20['Time'] <= end_time_1), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_2) & (df_s20['Time'] <= end_time_2), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_3) & (df_s20['Time'] <= end_time_3), 'Label'] = 1
df_s20.loc[(df_s20['Time'] >= start_time_4) & (df_s20['Time'] <= end_time_4), 'Label'] = 1

df_s20.to_csv('S20_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S20_HR_Label.csv')
df_BVP = pd.read_csv('S20_BVP_Label.csv')
df_EDA = pd.read_csv('S20_EDA_Label.csv')
df_TEMP = pd.read_csv('S20_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s20_merge = pd.merge(df_merge1, df_merge2)
df_s20_merge.to_csv('s20_merge.csv', index=False)

# %%
df_s21 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S21/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s21), 64):
    avg = df_s21[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s21 = pd.DataFrame({'BVP': averages})
result_df_s21.to_csv('result_S21_BVP.csv', index=False)

# %%
df_s21 = pd.read_csv('result_S21_BVP.csv')

start_time = 1646048637

df_s21['Time'] = [start_time + i for i in range(len(df_s21))]

df_s21.to_csv('S21_BVP.csv', index=False)

# %%
df_s21 = pd.read_csv('S21_BVP.csv')

start_time_1 = 1646049281
end_time_1 = 1646049695
start_time_2 = 1646050008
end_time_2 = 1646050635
start_time_3 = 1646050945
end_time_3 = 1646051050
start_time_4 = 1646051330
end_time_4 = 1646051640

df_s21['Label'] = 0

df_s21.loc[(df_s21['Time'] >= start_time_1) & (df_s21['Time'] <= end_time_1), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_2) & (df_s21['Time'] <= end_time_2), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_3) & (df_s21['Time'] <= end_time_3), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_4) & (df_s21['Time'] <= end_time_4), 'Label'] = 1

df_s21.to_csv('S21_BVP_Label.csv', index=False)

# %%
df_s21 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S21/HR.csv')
df_s21 = df_s21.iloc[1:]

start_time = 1646048647

df_s21['Time'] = [start_time + i for i in range(len(df_s21))]

df_s21.to_csv('S21_HR.csv', index=False)

# %%
df_s21 = pd.read_csv('S21_HR.csv')

start_time_1 = 1646049281
end_time_1 = 1646049695
start_time_2 = 1646050008
end_time_2 = 1646050635
start_time_3 = 1646050945
end_time_3 = 1646051050
start_time_4 = 1646051330
end_time_4 = 1646051640 

df_s21['Label'] = 0

df_s21.loc[(df_s21['Time'] >= start_time_1) & (df_s21['Time'] <= end_time_1), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_2) & (df_s21['Time'] <= end_time_2), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_3) & (df_s21['Time'] <= end_time_3), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_4) & (df_s21['Time'] <= end_time_4), 'Label'] = 1

df_s21.to_csv('S21_HR_Label.csv', index=False)

# %%
df_s21 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S21/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s21), 4):
    avg = df_s21[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s21 = pd.DataFrame({'EDA': averages})
result_df_s21.to_csv('result_S21_EDA.csv', index=False)

# %%
df_s21 = pd.read_csv('result_S21_EDA.csv')

start_time = 1646048637

df_s21['Time'] = [start_time + i for i in range(len(df_s21))]

df_s21.to_csv('S21_EDA.csv', index=False)

# %%
df_s21 = pd.read_csv('S21_EDA.csv')

start_time_1 = 1646049281
end_time_1 = 1646049695
start_time_2 = 1646050008
end_time_2 = 1646050635
start_time_3 = 1646050945
end_time_3 = 1646051050
start_time_4 = 1646051330
end_time_4 = 1646051640 

df_s21['Label'] = 0

df_s21.loc[(df_s21['Time'] >= start_time_1) & (df_s21['Time'] <= end_time_1), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_2) & (df_s21['Time'] <= end_time_2), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_3) & (df_s21['Time'] <= end_time_3), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_4) & (df_s21['Time'] <= end_time_4), 'Label'] = 1

df_s21.to_csv('S21_EDA_Label.csv', index=False)

# %%
df_s21 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S21/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s21), 4):
    avg = df_s21[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s21 = pd.DataFrame({'TEMP': averages})
result_df_s21.to_csv('result_S21_TEMP.csv', index=False)

# %%
df_s21 = pd.read_csv('result_S21_TEMP.csv')

start_time = 1646048637

df_s21['Time'] = [start_time + i for i in range(len(df_s21))]

df_s21.to_csv('S21_TEMP.csv', index=False)

# %%
df_s21 = pd.read_csv('S21_TEMP.csv')

start_time_1 = 1646049281
end_time_1 = 1646049695
start_time_2 = 1646050008
end_time_2 = 1646050635
start_time_3 = 1646050945
end_time_3 = 1646051050
start_time_4 = 1646051330
end_time_4 = 1646051640 

df_s21['Label'] = 0

df_s21.loc[(df_s21['Time'] >= start_time_1) & (df_s21['Time'] <= end_time_1), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_2) & (df_s21['Time'] <= end_time_2), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_3) & (df_s21['Time'] <= end_time_3), 'Label'] = 1
df_s21.loc[(df_s21['Time'] >= start_time_4) & (df_s21['Time'] <= end_time_4), 'Label'] = 1

df_s21.to_csv('S21_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S21_HR_Label.csv')
df_BVP = pd.read_csv('S21_BVP_Label.csv')
df_EDA = pd.read_csv('S21_EDA_Label.csv')
df_TEMP = pd.read_csv('S21_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s21_merge = pd.merge(df_merge1, df_merge2)
df_s21_merge.to_csv('s21_merge.csv', index=False)

# %%
df_s22 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S22/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s22), 64):
    avg = df_s22[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s22 = pd.DataFrame({'BVP': averages})
result_df_s22.to_csv('result_S22_BVP.csv', index=False)

# %%
df_s22 = pd.read_csv('result_S22_BVP.csv')

start_time = 1646050723

df_s22['Time'] = [start_time + i for i in range(len(df_s22))]

df_s22.to_csv('S22_BVP.csv', index=False)

# %%
df_s22 = pd.read_csv('S22_BVP.csv')

start_time_1 = 1646051284
end_time_1 = 1646051697
start_time_2 = 1646051979
end_time_2 = 1646052578
start_time_3 = 1646052898
end_time_3 = 1646053028
start_time_4 = 1646053297
end_time_4 = 1646053597

df_s22['Label'] = 0

df_s22.loc[(df_s22['Time'] >= start_time_1) & (df_s22['Time'] <= end_time_1), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_2) & (df_s22['Time'] <= end_time_2), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_3) & (df_s22['Time'] <= end_time_3), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_4) & (df_s22['Time'] <= end_time_4), 'Label'] = 1

df_s22.to_csv('S22_BVP_Label.csv', index=False)

# %%
df_s22 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S22/HR.csv')
df_s22 = df_s22.iloc[1:]

start_time = 1646050733

df_s22['Time'] = [start_time + i for i in range(len(df_s22))]

df_s22.to_csv('S22_HR.csv', index=False)

# %%
df_s22 = pd.read_csv('S22_HR.csv')

start_time_1 = 1646051284
end_time_1 = 1646051697
start_time_2 = 1646051979
end_time_2 = 1646052578
start_time_3 = 1646052898
end_time_3 = 1646053028
start_time_4 = 1646053297
end_time_4 = 1646053597

df_s22['Label'] = 0

df_s22.loc[(df_s22['Time'] >= start_time_1) & (df_s22['Time'] <= end_time_1), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_2) & (df_s22['Time'] <= end_time_2), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_3) & (df_s22['Time'] <= end_time_3), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_4) & (df_s22['Time'] <= end_time_4), 'Label'] = 1

df_s22.to_csv('S22_HR_Label.csv', index=False)

# %%
df_s22 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S22/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s22), 4):
    avg = df_s22[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s22 = pd.DataFrame({'EDA': averages})
result_df_s22.to_csv('result_S22_EDA.csv', index=False)

# %%
df_s22 = pd.read_csv('result_S22_EDA.csv')

start_time = 1646050723

df_s22['Time'] = [start_time + i for i in range(len(df_s22))]

df_s22.to_csv('S22_EDA.csv', index=False)

# %%
df_s22 = pd.read_csv('S22_EDA.csv')

start_time_1 = 1646051284
end_time_1 = 1646051697
start_time_2 = 1646051979
end_time_2 = 1646052578
start_time_3 = 1646052898
end_time_3 = 1646053028
start_time_4 = 1646053297
end_time_4 = 1646053597

df_s22['Label'] = 0

df_s22.loc[(df_s22['Time'] >= start_time_1) & (df_s22['Time'] <= end_time_1), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_2) & (df_s22['Time'] <= end_time_2), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_3) & (df_s22['Time'] <= end_time_3), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_4) & (df_s22['Time'] <= end_time_4), 'Label'] = 1

df_s22.to_csv('S22_EDA_Label.csv', index=False)

# %%
df_s22 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S22/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s22), 4):
    avg = df_s22[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s22 = pd.DataFrame({'TEMP': averages})
result_df_s22.to_csv('result_S22_TEMP.csv', index=False)

# %%
df_s22 = pd.read_csv('result_S22_TEMP.csv')

start_time = 1646050723

df_s22['Time'] = [start_time + i for i in range(len(df_s22))]

df_s22.to_csv('S22_TEMP.csv', index=False)

# %%
df_s22 = pd.read_csv('S22_TEMP.csv')

start_time_1 = 1646051284
end_time_1 = 1646051697
start_time_2 = 1646051979
end_time_2 = 1646052578
start_time_3 = 1646052898
end_time_3 = 1646053028
start_time_4 = 1646053297
end_time_4 = 1646053597

df_s22['Label'] = 0

df_s22.loc[(df_s22['Time'] >= start_time_1) & (df_s22['Time'] <= end_time_1), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_2) & (df_s22['Time'] <= end_time_2), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_3) & (df_s22['Time'] <= end_time_3), 'Label'] = 1
df_s22.loc[(df_s22['Time'] >= start_time_4) & (df_s22['Time'] <= end_time_4), 'Label'] = 1

df_s22.to_csv('S22_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S22_HR_Label.csv')
df_BVP = pd.read_csv('S22_BVP_Label.csv')
df_EDA = pd.read_csv('S22_EDA_Label.csv')
df_TEMP = pd.read_csv('S22_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s22_merge = pd.merge(df_merge1, df_merge2)
df_s22_merge.to_csv('s22_merge.csv', index=False)

# %%
df_s23 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S23/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s23), 64):
    avg = df_s23[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s23 = pd.DataFrame({'BVP': averages})
result_df_s23.to_csv('result_S23_BVP.csv', index=False)

# %%
df_s23 = pd.read_csv('result_S23_BVP.csv')

start_time = 1646052269

df_s23['Time'] = [start_time + i for i in range(len(df_s23))]

df_s23.to_csv('S23_BVP.csv', index=False)

# %%
df_s23 = pd.read_csv('S23_BVP.csv')

start_time_1 = 1646052857
end_time_1 = 1646053245
start_time_2 = 1646053595
end_time_2 = 1646054154
start_time_3 = 1646054442
end_time_3 = 1646054567
start_time_4 = 1646054876
end_time_4 = 1646055060

df_s23['Label'] = 0

df_s23.loc[(df_s23['Time'] >= start_time_1) & (df_s23['Time'] <= end_time_1), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_2) & (df_s23['Time'] <= end_time_2), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_3) & (df_s23['Time'] <= end_time_3), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_4) & (df_s23['Time'] <= end_time_4), 'Label'] = 1

df_s23.to_csv('S23_BVP_Label.csv', index=False)

# %%
df_s23 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S23/HR.csv')
df_s23 = df_s23.iloc[1:]

start_time = 1646052279

df_s23['Time'] = [start_time + i for i in range(len(df_s23))]

df_s23.to_csv('S23_HR.csv', index=False)

# %%
df_s23 = pd.read_csv('S23_HR.csv')

start_time_1 = 1646052857
end_time_1 = 1646053245
start_time_2 = 1646053595
end_time_2 = 1646054154
start_time_3 = 1646054442
end_time_3 = 1646054567
start_time_4 = 1646054876
end_time_4 = 1646055060

df_s23['Label'] = 0

df_s23.loc[(df_s23['Time'] >= start_time_1) & (df_s23['Time'] <= end_time_1), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_2) & (df_s23['Time'] <= end_time_2), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_3) & (df_s23['Time'] <= end_time_3), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_4) & (df_s23['Time'] <= end_time_4), 'Label'] = 1

df_s23.to_csv('S23_HR_Label.csv', index=False)

# %%
df_s23 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S23/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s23), 4):
    avg = df_s23[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s23 = pd.DataFrame({'EDA': averages})
result_df_s23.to_csv('result_S23_EDA.csv', index=False)

# %%
df_s23 = pd.read_csv('result_S23_EDA.csv')

start_time = 1646052269

df_s23['Time'] = [start_time + i for i in range(len(df_s23))]

df_s23.to_csv('S23_EDA.csv', index=False)

# %%
df_s23 = pd.read_csv('S23_EDA.csv')

start_time_1 = 1646052857
end_time_1 = 1646053245
start_time_2 = 1646053595
end_time_2 = 1646054154
start_time_3 = 1646054442
end_time_3 = 1646054567
start_time_4 = 1646054876
end_time_4 = 1646055060

df_s23['Label'] = 0

df_s23.loc[(df_s23['Time'] >= start_time_1) & (df_s23['Time'] <= end_time_1), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_2) & (df_s23['Time'] <= end_time_2), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_3) & (df_s23['Time'] <= end_time_3), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_4) & (df_s23['Time'] <= end_time_4), 'Label'] = 1

df_s23.to_csv('S23_EDA_Label.csv', index=False)

# %%
df_s23 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S23/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s23), 4):
    avg = df_s23[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s23 = pd.DataFrame({'TEMP': averages})
result_df_s23.to_csv('result_S23_TEMP.csv', index=False)

# %%
df_s23 = pd.read_csv('result_S23_TEMP.csv')

start_time = 1646052269

df_s23['Time'] = [start_time + i for i in range(len(df_s23))]

df_s23.to_csv('S23_TEMP.csv', index=False)

# %%
df_s23 = pd.read_csv('S23_TEMP.csv')

start_time_1 = 1646052857
end_time_1 = 1646053245
start_time_2 = 1646053595
end_time_2 = 1646054154
start_time_3 = 1646054442
end_time_3 = 1646054567
start_time_4 = 1646054876
end_time_4 = 1646055060

df_s23['Label'] = 0

df_s23.loc[(df_s23['Time'] >= start_time_1) & (df_s23['Time'] <= end_time_1), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_2) & (df_s23['Time'] <= end_time_2), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_3) & (df_s23['Time'] <= end_time_3), 'Label'] = 1
df_s23.loc[(df_s23['Time'] >= start_time_4) & (df_s23['Time'] <= end_time_4), 'Label'] = 1

df_s23.to_csv('S23_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S23_HR_Label.csv')
df_BVP = pd.read_csv('S23_BVP_Label.csv')
df_EDA = pd.read_csv('S23_EDA_Label.csv')
df_TEMP = pd.read_csv('S23_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s23_merge = pd.merge(df_merge1, df_merge2)
df_s23_merge.to_csv('s23_merge.csv', index=False)

# %%
df_s24 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S24/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s24), 64):
    avg = df_s24[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s24 = pd.DataFrame({'BVP': averages})
result_df_s24.to_csv('result_S24_BVP.csv', index=False)

# %%
df_s24 = pd.read_csv('result_S24_BVP.csv')

start_time = 1646059181

df_s24['Time'] = [start_time + i for i in range(len(df_s24))]

df_s24.to_csv('S24_BVP.csv', index=False)

# %%
df_s24 = pd.read_csv('S24_BVP.csv')

start_time_1 = 1646059893
end_time_1 = 1646060242
start_time_2 = 1646060563
end_time_2 = 1646061187
start_time_3 = 1646061488
end_time_3 = 1646061590
start_time_4 = 1646061887
end_time_4 = 1646062200

df_s24['Label'] = 0

df_s24.loc[(df_s24['Time'] >= start_time_1) & (df_s24['Time'] <= end_time_1), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_2) & (df_s24['Time'] <= end_time_2), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_3) & (df_s24['Time'] <= end_time_3), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_4) & (df_s24['Time'] <= end_time_4), 'Label'] = 1

df_s24.to_csv('S24_BVP_Label.csv', index=False)

# %%
df_s24 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S24/HR.csv')
df_s24 = df_s24.iloc[1:]

start_time = 1646059191

df_s24['Time'] = [start_time + i for i in range(len(df_s24))]

df_s24.to_csv('S24_HR.csv', index=False)

# %%
df_s24 = pd.read_csv('S24_HR.csv')

start_time_1 = 1646059893
end_time_1 = 1646060242
start_time_2 = 1646060563
end_time_2 = 1646061187
start_time_3 = 1646061488
end_time_3 = 1646061590
start_time_4 = 1646061887
end_time_4 = 1646062200


df_s24['Label'] = 0

df_s24.loc[(df_s24['Time'] >= start_time_1) & (df_s24['Time'] <= end_time_1), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_2) & (df_s24['Time'] <= end_time_2), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_3) & (df_s24['Time'] <= end_time_3), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_4) & (df_s24['Time'] <= end_time_4), 'Label'] = 1

df_s24.to_csv('S24_HR_Label.csv', index=False)

# %%
df_s24 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S24/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s24), 4):
    avg = df_s24[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s24 = pd.DataFrame({'EDA': averages})
result_df_s24.to_csv('result_S24_EDA.csv', index=False)

# %%
df_s24 = pd.read_csv('result_S24_EDA.csv')

start_time = 1646059181

df_s24['Time'] = [start_time + i for i in range(len(df_s24))]

df_s24.to_csv('S24_EDA.csv', index=False)

# %%
df_s24 = pd.read_csv('S24_EDA.csv')

start_time_1 = 1646059893
end_time_1 = 1646060242
start_time_2 = 1646060563
end_time_2 = 1646061187
start_time_3 = 1646061488
end_time_3 = 1646061590
start_time_4 = 1646061887
end_time_4 = 1646062200

df_s24['Label'] = 0

df_s24.loc[(df_s24['Time'] >= start_time_1) & (df_s24['Time'] <= end_time_1), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_2) & (df_s24['Time'] <= end_time_2), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_3) & (df_s24['Time'] <= end_time_3), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_4) & (df_s24['Time'] <= end_time_4), 'Label'] = 1

df_s24.to_csv('S24_EDA_Label.csv', index=False)

# %%
df_s24 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S24/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s24), 4):
    avg = df_s24[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s24 = pd.DataFrame({'TEMP': averages})
result_df_s24.to_csv('result_S24_TEMP.csv', index=False)

# %%
df_s24 = pd.read_csv('result_S24_TEMP.csv')

start_time = 1646059181

df_s24['Time'] = [start_time + i for i in range(len(df_s24))]

df_s24.to_csv('S24_TEMP.csv', index=False)

# %%
df_s24 = pd.read_csv('S24_TEMP.csv')

start_time_1 = 1646059893
end_time_1 = 1646060242
start_time_2 = 1646060563
end_time_2 = 1646061187
start_time_3 = 1646061488
end_time_3 = 1646061590
start_time_4 = 1646061887
end_time_4 = 1646062200

df_s24['Label'] = 0

df_s24.loc[(df_s24['Time'] >= start_time_1) & (df_s24['Time'] <= end_time_1), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_2) & (df_s24['Time'] <= end_time_2), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_3) & (df_s24['Time'] <= end_time_3), 'Label'] = 1
df_s24.loc[(df_s24['Time'] >= start_time_4) & (df_s24['Time'] <= end_time_4), 'Label'] = 1

df_s24.to_csv('S24_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S24_HR_Label.csv')
df_BVP = pd.read_csv('S24_BVP_Label.csv')
df_EDA = pd.read_csv('S24_EDA_Label.csv')
df_TEMP = pd.read_csv('S24_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s24_merge = pd.merge(df_merge1, df_merge2)
df_s24_merge.to_csv('s24_merge.csv', index=False)

# %%
df_s25 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S25/BVP.csv')

column_to_average = 'BVP'

averages = []

for i in range(1, len(df_s25), 64):
    avg = df_s25[column_to_average].iloc[i:i+64].mean()
    averages.append(avg)

result_df_s25 = pd.DataFrame({'BVP': averages})
result_df_s25.to_csv('result_S25_BVP.csv', index=False)

# %%
df_s25 = pd.read_csv('result_S25_BVP.csv')

start_time = 1646061149

df_s25['Time'] = [start_time + i for i in range(len(df_s25))]

df_s25.to_csv('S25_BVP.csv', index=False)

# %%
df_s25 = pd.read_csv('S25_BVP.csv')

start_time_1 = 1646061766
end_time_1 = 1646062157
start_time_2 = 1646062471
end_time_2 = 1646063052
start_time_3 = 1646063322
end_time_3 = 1646063411
start_time_4 = 1646063755
end_time_4 = 1646064115

df_s25['Label'] = 0

df_s25.loc[(df_s25['Time'] >= start_time_1) & (df_s25['Time'] <= end_time_1), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_2) & (df_s25['Time'] <= end_time_2), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_3) & (df_s25['Time'] <= end_time_3), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_4) & (df_s25['Time'] <= end_time_4), 'Label'] = 1

df_s25.to_csv('S25_BVP_Label.csv', index=False)

# %%
df_s25 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S25/HR.csv')
df_s25 = df_s25.iloc[1:]

start_time = 1646061159

df_s25['Time'] = [start_time + i for i in range(len(df_s25))]

df_s25.to_csv('S25_HR.csv', index=False)

# %%
df_s25 = pd.read_csv('S25_HR.csv')

start_time_1 = 1646061766
end_time_1 = 1646062157
start_time_2 = 1646062471
end_time_2 = 1646063052
start_time_3 = 1646063322
end_time_3 = 1646063411
start_time_4 = 1646063755
end_time_4 = 1646064115

df_s25['Label'] = 0

df_s25.loc[(df_s25['Time'] >= start_time_1) & (df_s25['Time'] <= end_time_1), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_2) & (df_s25['Time'] <= end_time_2), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_3) & (df_s25['Time'] <= end_time_3), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_4) & (df_s25['Time'] <= end_time_4), 'Label'] = 1

df_s25.to_csv('S25_HR_Label.csv', index=False)

# %%
df_s25 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S25/EDA.csv')

column_to_average = 'EDA'

averages = []

for i in range(1, len(df_s25), 4):
    avg = df_s25[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s25 = pd.DataFrame({'EDA': averages})
result_df_s25.to_csv('result_S25_EDA.csv', index=False)

# %%
df_s25 = pd.read_csv('result_S25_EDA.csv')

start_time = 1646061149

df_s25['Time'] = [start_time + i for i in range(len(df_s25))]

df_s25.to_csv('S25_EDA.csv', index=False)

# %%
df_s25 = pd.read_csv('S25_EDA.csv')

start_time_1 = 1646061766
end_time_1 = 1646062157
start_time_2 = 1646062471
end_time_2 = 1646063052
start_time_3 = 1646063322
end_time_3 = 1646063411
start_time_4 = 1646063755
end_time_4 = 1646064115

df_s25['Label'] = 0

df_s25.loc[(df_s25['Time'] >= start_time_1) & (df_s25['Time'] <= end_time_1), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_2) & (df_s25['Time'] <= end_time_2), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_3) & (df_s25['Time'] <= end_time_3), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_4) & (df_s25['Time'] <= end_time_4), 'Label'] = 1

df_s25.to_csv('S25_EDA_Label.csv', index=False)

# %%
df_s25 = pd.read_csv('C:/Users/tusha/Downloads/CE888/Stress-Predict-Dataset-main/Raw_data/S25/TEMP.csv')

column_to_average = 'TEMP'

averages = []

for i in range(1, len(df_s25), 4):
    avg = df_s25[column_to_average].iloc[i:i+4].mean()
    averages.append(avg)

result_df_s25 = pd.DataFrame({'TEMP': averages})
result_df_s25.to_csv('result_S25_TEMP.csv', index=False)

# %%
df_s25 = pd.read_csv('result_S25_TEMP.csv')

start_time = 1646061149

df_s25['Time'] = [start_time + i for i in range(len(df_s25))]

df_s25.to_csv('S25_TEMP.csv', index=False)

# %%
df_s25 = pd.read_csv('S25_TEMP.csv')

start_time_1 = 1646061766
end_time_1 = 1646062157
start_time_2 = 1646062471
end_time_2 = 1646063052
start_time_3 = 1646063322
end_time_3 = 1646063411
start_time_4 = 1646063755
end_time_4 = 1646064115

df_s25['Label'] = 0

df_s25.loc[(df_s25['Time'] >= start_time_1) & (df_s25['Time'] <= end_time_1), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_2) & (df_s25['Time'] <= end_time_2), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_3) & (df_s25['Time'] <= end_time_3), 'Label'] = 1
df_s25.loc[(df_s25['Time'] >= start_time_4) & (df_s25['Time'] <= end_time_4), 'Label'] = 1

df_s25.to_csv('S25_TEMP_Label.csv', index=False)

# %%
df_HR = pd.read_csv('S25_HR_Label.csv')
df_BVP = pd.read_csv('S25_BVP_Label.csv')
df_EDA = pd.read_csv('S25_EDA_Label.csv')
df_TEMP = pd.read_csv('S25_TEMP_Label.csv')

df_merge1 = pd.merge(df_HR, df_BVP, on=['Time', 'Label'])
df_merge2 = pd.merge(df_TEMP, df_EDA, on=['Time', 'Label'])
df_s25_merge = pd.merge(df_merge1, df_merge2)
df_s25_merge.to_csv('s25_merge.csv', index=False)

# %% [markdown]
# Merging csv files for train data

# %%
S01 = pd.read_csv('s01_merge.csv')

S02 = pd.read_csv('s02_merge.csv')
S01 = pd.concat([S01, S02], axis=0, ignore_index=True)

S03 = pd.read_csv('s03_merge.csv')
S01 = pd.concat([S01, S03], axis=0, ignore_index=True)

S04 = pd.read_csv('s04_merge.csv')
S01 = pd.concat([S01, S04], axis=0, ignore_index=True)

S05 = pd.read_csv('s05_merge.csv')
S01 = pd.concat([S01, S05], axis=0, ignore_index=True)

S06 = pd.read_csv('s06_merge.csv')
S01 = pd.concat([S01, S06], axis=0, ignore_index=True)

S07 = pd.read_csv('s07_merge.csv')
S01 = pd.concat([S01, S07], axis=0, ignore_index=True)

S08 = pd.read_csv('s08_merge.csv')
S01 = pd.concat([S01, S08], axis=0, ignore_index=True)

S09 = pd.read_csv('s09_merge.csv')
S01 = pd.concat([S01, S09], axis=0, ignore_index=True)

S10 = pd.read_csv('s10_merge.csv')
S01 = pd.concat([S01, S10], axis=0, ignore_index=True)

S11 = pd.read_csv('s11_merge.csv')
S01 = pd.concat([S01, S11], axis=0, ignore_index=True)

S12 = pd.read_csv('s12_merge.csv')
S01 = pd.concat([S01, S12], axis=0, ignore_index=True)

S13 = pd.read_csv('s13_merge.csv')
S01 = pd.concat([S01, S13], axis=0, ignore_index=True)

S14 = pd.read_csv('s14_merge.csv')
S01 = pd.concat([S01, S14], axis=0, ignore_index=True)

S15 = pd.read_csv('s15_merge.csv')
S01 = pd.concat([S01, S15], axis=0, ignore_index=True)

S16 = pd.read_csv('s16_merge.csv')
S01 = pd.concat([S01, S16], axis=0, ignore_index=True)

S17 = pd.read_csv('s17_merge.csv')
S01 = pd.concat([S01, S17], axis=0, ignore_index=True)

S18 = pd.read_csv('s18_merge.csv')
S01 = pd.concat([S01, S18], axis=0, ignore_index=True)

S19 = pd.read_csv('s19_merge.csv')
S01 = pd.concat([S01, S19], axis=0, ignore_index=True)

S20 = pd.read_csv('s20_merge.csv')
S01 = pd.concat([S01, S20], axis=0, ignore_index=True)

S01.to_csv('Train.csv', index=False)

# %% [markdown]
# Merging csv files for test data

# %%
S21 = pd.read_csv('s21_merge.csv')

S22 = pd.read_csv('s22_merge.csv')
S21 = pd.concat([S21, S22], axis=0, ignore_index=True)

S23 = pd.read_csv('s23_merge.csv')
S21 = pd.concat([S21, S23], axis=0, ignore_index=True)

S24 = pd.read_csv('s24_merge.csv')
S21 = pd.concat([S21, S24], axis=0, ignore_index=True)

S25 = pd.read_csv('s25_merge.csv')
S21 = pd.concat([S21, S25], axis=0, ignore_index=True)

S21.to_csv('Test.csv', index=False)

# %%
df_train = pd.read_csv('Train.csv')
df_test = pd.read_csv('Test.csv')

# %%
df_train
# Out:
#           HR        Time  Label        BVP   TEMP       EDA
# 0      83.00  1644226061      0  15.760000  28.39  0.111789
# 1      83.00  1644226062      0 -41.792500  28.39  0.166243
# 2      72.67  1644226063      0  32.554219  28.39  0.165602
# 3      87.00  1644226064      0  72.609063  28.39  0.166243
# 4      80.00  1644226065      0  -2.659531  28.37  0.165602
# ...      ...         ...    ...        ...    ...       ...
# 66566  88.53  1646045178      0   5.927031  31.95  1.597493
# 66567  88.47  1646045179      0   4.496406  31.95  1.590766
# 66568  88.38  1646045180      0  68.136562  31.99  1.602298
# 66569  88.27  1646045181      0 -69.230156  31.97  1.716657
# 66570  88.12  1646045182      0 -25.466875  31.97  1.809874
#
# [66571 rows x 6 columns]

# %%
df_test
# Out:
#           HR        Time  Label        BVP   TEMP       EDA
# 0      59.00  1646048647      0  44.433750  31.63  0.813661
# 1      58.50  1646048648      0  15.152188  31.59  0.811098
# 2      80.00  1646048649      0 -24.150938  31.61  0.801808
# 3      84.50  1646048650      0   7.443125  31.57  0.800207
# 4      82.40  1646048651      0  59.234219  31.57  0.768494
# ...      ...         ...    ...        ...    ...       ...
# 15809  70.37  1646064356      0  -0.793281  29.21  0.883049
# 15810  70.22  1646064357      0   2.743281  29.21  0.881768
# 15811  70.03  1646064358      0   0.482969  29.19  0.881768
# 15812  69.85  1646064359      0  -1.222344  29.23  0.879845
# 15813  69.73  1646064360      0 -19.164219  29.19  0.878564
#
# [15814 rows x 6 columns]

# %% [markdown]
# Separating features and target variable for train model

# %%
df_train_model = df_train.drop(columns = 'Label')
df_train_target = df_train.iloc[:,-4]
df_train_model
# Out:
#           HR        Time        BVP   TEMP       EDA
# 0      83.00  1644226061  15.760000  28.39  0.111789
# 1      83.00  1644226062 -41.792500  28.39  0.166243
# 2      72.67  1644226063  32.554219  28.39  0.165602
# 3      87.00  1644226064  72.609063  28.39  0.166243
# 4      80.00  1644226065  -2.659531  28.37  0.165602
# ...      ...         ...        ...    ...       ...
# 66566  88.53  1646045178   5.927031  31.95  1.597493
# 66567  88.47  1646045179   4.496406  31.95  1.590766
# 66568  88.38  1646045180  68.136562  31.99  1.602298
# 66569  88.27  1646045181 -69.230156  31.97  1.716657
# 66570  88.12  1646045182 -25.466875  31.97  1.809874
#
# [66571 rows x 5 columns]

# %%
df_train_target
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 66566    0
# 66567    0
# 66568    0
# 66569    0
# 66570    0
# Name: Label, Length: 66571, dtype: int64

# %% [markdown]
# Separating features and target variable for test model

# %%
df_test_model = df_test.drop(columns = 'Label')
df_test_target = df_test.iloc[:,-4]
df_test_model
# Out:
#           HR        Time        BVP   TEMP       EDA
# 0      59.00  1646048647  44.433750  31.63  0.813661
# 1      58.50  1646048648  15.152188  31.59  0.811098
# 2      80.00  1646048649 -24.150938  31.61  0.801808
# 3      84.50  1646048650   7.443125  31.57  0.800207
# 4      82.40  1646048651  59.234219  31.57  0.768494
# ...      ...         ...        ...    ...       ...
# 15809  70.37  1646064356  -0.793281  29.21  0.883049
# 15810  70.22  1646064357   2.743281  29.21  0.881768
# 15811  70.03  1646064358   0.482969  29.19  0.881768
# 15812  69.85  1646064359  -1.222344  29.23  0.879845
# 15813  69.73  1646064360 -19.164219  29.19  0.878564
#
# [15814 rows x 5 columns]

# %%
df_test_target
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15809    0
# 15810    0
# 15811    0
# 15812    0
# 15813    0
# Name: Label, Length: 15814, dtype: int64

# %% [markdown]
# Applying Random Forest Classifier

# %%
df_Random = RandomForestClassifier(n_estimators=100)

df_Random.fit(df_train_model, df_train_target)

predictions = df_Random.predict(df_test_model)

df_Random_accuracy = df_Random.score(df_test_model, df_test_target)

print(f"Random Forest accuracy: {df_Random_accuracy}")
print(classification_report(df_test_target, predictions))
# Out:
# Random Forest accuracy: 0.5658277475654483
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72      8831
#            1       0.93      0.02      0.04      6983
#
#     accuracy                           0.57     15814
#    macro avg       0.74      0.51      0.38     15814
# weighted avg       0.72      0.57      0.42     15814

# %% [markdown]
# Applying Decision Tree Classifier

# %%
df_Decision = DecisionTreeClassifier()

df_Decision.fit(df_train_model, df_train_target)

predictions = df_Decision.predict(df_test_model)

df_Decision_accuracy = df_Decision.score(df_test_model, df_test_target)
print(f"Decision Tree accuracy: {df_Decision_accuracy}")
print(classification_report(df_test_target, predictions))
# Out:
# Decision Tree accuracy: 0.5546983685342102
#               precision    recall  f1-score   support
#
#            0       0.58      0.72      0.64      8831
#            1       0.49      0.35      0.41      6983
#
#     accuracy                           0.55     15814
#    macro avg       0.54      0.53      0.53     15814
# weighted avg       0.54      0.55      0.54     15814

# %% [markdown]
# Applying Logistic Regression model

# %%
df_scaler = MinMaxScaler()
train_minmax = df_scaler.fit_transform(df_train_model)
test_minmax = df_scaler.transform(df_test_model)

df_std = StandardScaler()
train = df_std.fit_transform(train_minmax)
test = df_std.transform(test_minmax)

df_Logistic = LogisticRegression()
df_Logistic.fit(train, df_train_target)

df_pred = df_Logistic.predict(test)

df_Logistic_accuracy = df_Logistic.score(test, df_test_target)
print(f"Logistic regression Accuracy: {df_Logistic_accuracy}")
# Out:
# Logistic regression Accuracy: 0.5772100670292146

# %% [markdown]
# Applying Neural Network model

# %%
df_scaler = MinMaxScaler()
train_minmax = df_scaler.fit_transform(df_train_model)
test_minmax = df_scaler.transform(df_test_model)

df_std = StandardScaler()
train = df_std.fit_transform(train_minmax)
test = df_std.transform(test_minmax)

df_NN = Sequential()
df_NN.add(Dense(64, input_dim=train.shape[1], activation='relu'))
df_NN.add(Dense(32, activation='relu'))
df_NN.add(Dense(1, activation='sigmoid'))

df_NN.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

df_NN.fit(train, df_train_target, epochs=10, batch_size=32)

df_NN_accuracy = model.evaluate(test, df_test_target)[1]
print(f"Neural Network Accuracy: {df_NN_accuracy}")
# Out:
# Epoch 1/10
# 2081/2081 [==============================] - 5s 2ms/step - loss: 0.6368 - accuracy: 0.6281
# Epoch 2/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.6043 - accuracy: 0.6598
# Epoch 3/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5864 - accuracy: 0.6790
# Epoch 4/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5712 - accuracy: 0.6900
# Epoch 5/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5578 - accuracy: 0.7023
# Epoch 6/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5445 - accuracy: 0.7137
# Epoch 7/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5317 - accuracy: 0.7253
# Epoch 8/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5195 - accuracy: 0.7336
# Epoch 9/10
# 2081/2081 [==============================] - 4s 2ms/step - loss: 0.5114 - accuracy: 0.7388
# Epoch 10/10
# ...

# %% [markdown]
# Plotting HR and Label from Train data of 20 students  on boxplot

# %%
df_plot = pd.read_csv('Train.csv')

df_grp = df_plot.groupby('Label')['HR']

df_data = [df_grp.get_group(label) for label in df_plot['Label'].unique()]

tw, pl = plt.subplots(figsize=(10, 6))
pl.boxplot(df_data)
pl.set_xticklabels(df_plot['Label'].unique())
pl.set_ylabel('HR Values')
# Out:
# Text(0, 0.5, 'HR Values')

# %% [markdown]
# Plotting EDA and Label from Train data of 20 students on boxplot

# %%
df_plot = pd.read_csv('Train.csv')

df_grp = df_plot.groupby('Label')['EDA']

df_data = [df_grp.get_group(label) for label in df_plot['Label'].unique()]

tw, pl = plt.subplots(figsize=(10, 6))
pl.boxplot(df_data)
pl.set_xticklabels(df_plot['Label'].unique())
pl.set_ylabel('EDA Values')
# Out:
# Text(0, 0.5, 'EDA Values')

# %% [markdown]
# Plotting TMEP and Label from Train data of 20 students on boxplot

# %%
df_plot = pd.read_csv('Train.csv')

df_grp = df_plot.groupby('Label')['TEMP']

df_data = [df_grp.get_group(label) for label in df_plot['Label'].unique()]

tw, pl = plt.subplots(figsize=(10, 6))
pl.boxplot(df_data)
pl.set_xticklabels(df_plot['Label'].unique())
pl.set_ylabel('TEMP Values')
# Out:
# Text(0, 0.5, 'TEMP Values')
